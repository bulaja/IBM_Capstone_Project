# %%
#upload our toronto_coordinates.csv file
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ae56f721-6aef-453d-9981-620814263160" name="files[]" multiple disabled />
#      <output id="result-ae56f721-6aef-453d-9981-620814263160">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving toronto_coordinates.csv to toronto_coordinates.csv

# %%
import numpy as np
import pandas as pd
from geopy.geocoders import Nominatim
import folium # map rendering library
import requests
from sklearn.cluster import KMeans
import matplotlib.cm as cm
import matplotlib.colors as colors

# %%
toronto_df_new = pd.read_csv("toronto_coordinates.csv")

# %%
toronto_df_new.head()
# Out:
#   PostalCode      Borough  ...   Latitude  Longitude
# 0        M1B  Scarborough  ...  43.806686 -79.194353
# 1        M1C  Scarborough  ...  43.784535 -79.160497
# 2        M1E  Scarborough  ...  43.763573 -79.188711
# 3        M1G  Scarborough  ...  43.770992 -79.216917
# 4        M1H  Scarborough  ...  43.773136 -79.239476
#
# [5 rows x 5 columns]

# %%
toronto_df_new
# Out:
#     PostalCode      Borough  ...   Latitude  Longitude
# 0          M1B  Scarborough  ...  43.806686 -79.194353
# 1          M1C  Scarborough  ...  43.784535 -79.160497
# 2          M1E  Scarborough  ...  43.763573 -79.188711
# 3          M1G  Scarborough  ...  43.770992 -79.216917
# 4          M1H  Scarborough  ...  43.773136 -79.239476
# ..         ...          ...  ...        ...        ...
# 98         M9N         York  ...  43.706876 -79.518188
# 99         M9P    Etobicoke  ...  43.696319 -79.532242
# 100        M9R    Etobicoke  ...  43.688905 -79.554724
# 101        M9V    Etobicoke  ...  43.739416 -79.588437
# 102        M9W    Etobicoke  ...  43.706748 -79.594054
#
# [103 rows x 5 columns]

# %%
address = 'Toronto'
geolocator = Nominatim(user_agent="my-application")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.6534817, -79.3839347.

# %%
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(toronto_df_new['Latitude'], toronto_df_new['Longitude'], toronto_df_new['Borough'], toronto_df_new['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=7,
        popup=label,
        color='green',
        fill=True,
        fill_color='#3564cc',
        fill_opacity=0.6).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
borough_names = list(toronto_df_new.Borough.unique())

borough_with_toronto = []

for x in borough_names:
    if "toronto" in x.lower():
        borough_with_toronto.append(x)
        
borough_with_toronto
# Out:
# ['East Toronto', 'Central Toronto', 'Downtown Toronto', 'West Toronto']

# %%
# create a new DataFrame with only boroughs that contain the word Toronto
toronto_df_new = toronto_df_new[toronto_df_new['Borough'].isin(borough_with_toronto)].reset_index(drop=True)
print(toronto_df_new.shape)
toronto_df_new.head()
# Out:
# (39, 5)
#   PostalCode          Borough  ...   Latitude  Longitude
# 0        M4E     East Toronto  ...  43.676357 -79.293031
# 1        M4K     East Toronto  ...  43.679557 -79.352188
# 2        M4L     East Toronto  ...  43.668999 -79.315572
# 3        M4M     East Toronto  ...  43.659526 -79.340923
# 4        M4N  Central Toronto  ...  43.728020 -79.388790
#
# [5 rows x 5 columns]

# %%
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(toronto_df_new['Latitude'], toronto_df_new['Longitude'], toronto_df_new['Borough'], toronto_df_new['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='red',
        fill=True,
        fill_color='#5242cc',
        fill_opacity=0.7).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
CLIENT_ID = 'OQMW5IHQXDZJ3A1FMOFPIJEXKCQ5I3MYPDQ2PVCSRAVDR5WE' # your Foursquare ID
CLIENT_SECRET = 'CWGPFHHGQ4EDEHSVTU3W1ZS3SEJVKM1RYZRZWCEAR1YEFHAL'  # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: OQMW5IHQXDZJ3A1FMOFPIJEXKCQ5I3MYPDQ2PVCSRAVDR5WE
# CLIENT_SECRET:CWGPFHHGQ4EDEHSVTU3W1ZS3SEJVKM1RYZRZWCEAR1YEFHAL

# %%
# Foursquare API call
radius = 500
LIMIT = 100

venues = []

for lat, long, post, borough, neighborhood in zip(toronto_df_new['Latitude'], toronto_df_new['Longitude'], toronto_df_new['PostalCode'], toronto_df_new['Borough'], 
                                                  toronto_df_new['Neighborhood']):
    url = "https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&v={} \
     &ll={},{}&radius={}&limit={}".format(
        CLIENT_ID,
        CLIENT_SECRET,
        VERSION,
        lat,
        long,
        radius, 
        LIMIT)
    
    results = requests.get(url).json()["response"]['groups'][0]['items']
    
    for venue in results:
        venues.append((
            post, 
            borough,
            neighborhood,
            lat, 
            long, 
            venue['venue']['name'], 
            venue['venue']['location']['lat'], 
            venue['venue']['location']['lng'],  
            venue['venue']['categories'][0]['name']))

# %%
#just checking
venues
# Out:
# [('M4E',
#   'East Toronto',
#   'The Beaches',
#   43.67635739999999,
#   -79.2930312,
#   'Glen Manor Ravine',
#   43.67682094413784,
#   -79.29394208780985,
#   'Trail'),
#  ('M4E',
#   'East Toronto',
#   'The Beaches',
#   43.67635739999999,
#   -79.2930312,
#   'The Big Carrot Natural Food Market',
#   43.678879,
#   -79.297734,
#   'Health Food Store'),
#  ('M4E',
#   'East Toronto',
#   'The Beaches',
#   43.67635739999999,
#   -79.2930312,
#   'Grover Pub and Grub',
#   43.679181434941015,
#   -79.29721535878515,
#   'Pub'),
#  ('M4E',
#   'East Toronto',
#   'The Beaches',
#   43.67635739999999,
#   -79.2930312,
#   'Glen Stewart Park',
#   43.67527822698259,
#   -79.2946465494184,
#   'Park'),
#  ('M4E',
#   'East Toronto',
#   'The Beaches',
#   43.67635739999999,
#   -79.2930312,
#   'Upper Beaches',
#   43.68056321147582,
#   -79.2928688743688,
#   'Neighborhood'),
#  ('M4K',
#   'East Toronto',
#   'The Danforth West, Riverdale',
#   43.6795571,
#   -79.352188,
#   'MenEssentials',
#   43.677820068604575,
#   -79.35126543045044,
#   'Cosmetics Shop'),
#  ('M4K',
#   'East Toronto',
#   'The Danforth West, Riverdale',
#   43.6795571,
#   -79.352188,
#   'Pantheon',
#   43.67762124481265,
#   -79.35143390043564,
#   'Greek Restaurant'),
#  ('M4K',
#   'East Toronto',
#   'The Danforth West, Riverdale',
#   43.6795571,
#   -79.352188,
#   'Cafe Fiorentina',
#   43.677743,
#   -79.350115,
#   'Italian Restaurant'),
#  ('M4K',
#   'East Toronto',
#   'The Danforth West, Riverdale',
#   43.6795571,
#   -79.352188,
#   'Dolce Gelato',
#   43.677772998450614,
#   -79.35118737317053,
#   'Ice Cream Shop'),
#  ('M4K',
#   'East Toronto',
#   'The Danforth West, Riverdale',
#   43.6795571,
#   -79.352188,
#   'La Diperie',
#   43.67753,
#   -79.352295,
#   'Ice Cream Shop'),
#  ('M4K',
#   'East Toronto',
#   'The Danforth West, Riverdale',
#   43.6795571,
#   -79.352188,
#   'Moksha Yoga Danforth',
#   43.67762174479883,
#   -79.3521159367257,
#   'Yoga Studio'),
#  ('M4K',
#   'East Toronto',
#   'The Danforth West, Riverdale',
#   43.6795571,
#   -79.352188,
#   'Mezes',
#   43.6779622615441,
#   -79.35019606997218,
#   'Greek Restaurant'),
#  ('M4K',
#   'East Toronto',
#   'The Danforth West, Riverdale',
#   43.6795571,
#   -79.352188,
#   'Louis Cifer Brew Works',
#   43.677662745359996,
#   -79.3513125762371,
#   'Brewery'),
#  ('M4K',
#   'East Toronto',
#   'The Danforth West, Riverdale',
#   43.6795571,
#   -79.352188,
#   'Alexandros',
#   43.67830448799868,
#   -79.34948556208978,
#   'Greek Restaurant'),
#  ('M4K',
#   'East Toronto',
#   'The Danforth West, Riverdale',
#   43.6795571,
#   -79.352188,
#   'Valley Farm Produce',
#   43.677999294687275,
#   -79.3499690927287,
#   'Fruit & Vegetable Store'),
#  ('M4K',
#   'East Toronto',
#   'The Danforth West, Riverdale',
#   43.6795571,
#   -79.352188,
#   '7 Numbers',
#   43.677061774959824,
#   -79.35393428891682,
#   'Italian Restaurant'),
#  ('M4K',
#   'East Toronto',
#   'The Danforth West, Riverdale',
#   43.6795571,
#   -79.352188,
#   'The Auld Spot Pub',
#   43.67733505610778,
#   -79.35312964755529,
#   'Pub'),
#  ('M4K',
#   'East Toronto',
#   'The Danforth West, Riverdale',
#   43.6795571,
#   -79.352188,
#   'Caffé Demetre',
#   43.67768266377745,
#   -79.35160842812537,
#   'Dessert Shop'),
#  ('M4K',
#   'East Toronto',
#   'The Danforth West, Riverdale',
#   43.6795571,
#   -79.352188,
#   'Rikkochez',
#   43.677267,
#   -79.353274,
#   'Restaurant'),
#  ('M4K',
#   'East Toronto',
#   'The Danforth West, Riverdale',
#   43.6795571,
#   -79.352188,
#   'Pizzeria Libretto',
#   43.678488633358,
#   -79.34757579277853,
#   'Pizza Place'),
#  ('M4K',
#   'East Toronto',
#   'The Danforth West, Riverdale',
#   43.6795571,
#   -79.352188,
#   'The Big Carrot Organic Juice Bar',
#   43.677438,
#   -79.352683,
#   'Juice Bar'),
#  ('M4K',
#   'East Toronto',
#   'The Danforth West, Riverdale',
#   43.6795571,
#   -79.352188,
#   'Re: Reading',
#   43.678506570428084,
#   -79.34767758382526,
#   'Bookstore'),
#  ('M4K',
#   'East Toronto',
#   'The Danforth West, Riverdale',
#   43.6795571,
#   -79.352188,
#   'Messini Authentic Gyros',
#   43.677827494513096,
#   -79.35056873157725,
#   'Greek Restaurant'),
#  ('M4K',
#   'East Toronto',
#   'The Danforth West, Riverdale',
#   43.6795571,
#   -79.352188,
#   'Don Valley Trail',
#   43.67633091997674,
#   -79.35392333297455,
#   'Trail'),
#  ('M4K',
#   'East Toronto',
#   'The Danforth West, Riverdale',
#   43.6795571,
#   -79.352188,
#   'Tsaa Tea Shop',
#   43.67776898684133,
#   -79.35130446081268,
#   'Bubble Tea Shop'),
#  ('M4K',
#   'East Toronto',
#   'The Danforth West, Riverdale',
#   43.6795571,
#   -79.352188,
#   'IQ Living',
#   43.678477,
#   -79.347811,
#   'Furniture / Home Store'),
#  ('M4K',
#   'East Toronto',
#   'The Danforth West, Riverdale',
#   43.6795571,
#   -79.352188,
#   'Bulk Barn',
#   43.67678989740336,
#   -79.35586511284247,
#   'Grocery Store'),
#  ('M4K',
#   'East Toronto',
#   'The Danforth West, Riverdale',
#   43.6795571,
#   -79.352188,
#   "Christina's On The Danforth",
#   43.678239784878826,
#   -79.34918494943804,
#   'Greek Restaurant'),
#  ('M4K',
#   'East Toronto',
#   'The Danforth West, Riverdale',
#   43.6795571,
#   -79.352188,
#   'Urban Nails',
#   43.676667789021906,
#   -79.35660190332753,
#   'Spa'),
#  ('M4K',
#   'East Toronto',
#   'The Danforth West, Riverdale',
#   43.6795571,
#   -79.352188,
#   'Kalyvia',
#   43.6779727,
#   -79.3512077,
#   'Greek Restaurant'),
#  ('M4K',
#   'East Toronto',
#   'The Danforth West, Riverdale',
#   43.6795571,
#   -79.352188,
#   'Marvel Coffee Co.',
#   43.678629530863844,
#   -79.34746013725268,
#   'Coffee Shop'),
#  ('M4K',
#   'East Toronto',
#   'The Danforth West, Riverdale',
#   43.6795571,
#   -79.352188,
#   'Astoria Shish Kebob House',
#   43.677596,
#   -79.351738,
#   'Greek Restaurant'),
#  ('M4K',
#   'East Toronto',
#   'The Danforth West, Riverdale',
#   43.6795571,
#   -79.352188,
#   'Dough Bakeshop',
#   43.67664308520287,
#   -79.35684634585105,
#   'Bakery'),
#  ('M4K',
#   'East Toronto',
#   'The Danforth West, Riverdale',
#   43.6795571,
#   -79.352188,
#   "Athen's Pastries",
#   43.67816589533113,
#   -79.34892679522846,
#   'Greek Restaurant'),
#  ('M4K',
#   'East Toronto',
#   'The Danforth West, Riverdale',
#   43.6795571,
#   -79.352188,
#   "Simone's Caribbean Restaurant",
#   43.67865547474292,
#   -79.34658157954753,
#   'Caribbean Restaurant'),
#  ('M4K',
#   'East Toronto',
#   'The Danforth West, Riverdale',
#   43.6795571,
#   -79.352188,
#   'Cafe Frappe',
#   43.67812618087551,
#   -79.34843379217203,
#   'Coffee Shop'),
#  ('M4K',
#   'East Toronto',
#   'The Danforth West, Riverdale',
#   43.6795571,
#   -79.352188,
#   'Leonidas Chocolates Cafe',
#   43.67811808012494,
#   -79.34948504099059,
#   'Café'),
#  ('M4K',
#   'East Toronto',
#   'The Danforth West, Riverdale',
#   43.6795571,
#   -79.352188,
#   'Sher-E-Punjab',
#   43.67730788939673,
#   -79.35306551709385,
#   'Indian Restaurant'),
#  ('M4K',
#   'East Toronto',
#   'The Danforth West, Riverdale',
#   43.6795571,
#   -79.352188,
#   'Bar Oak',
#   43.67793098663968,
#   -79.34872380466781,
#   'Lounge'),
#  ('M4K',
#   'East Toronto',
#   'The Danforth West, Riverdale',
#   43.6795571,
#   -79.352188,
#   "Menchie's",
#   43.67830909198205,
#   -79.34810528402672,
#   'Frozen Yogurt Shop'),
#  ('M4K',
#   'East Toronto',
#   'The Danforth West, Riverdale',
#   43.6795571,
#   -79.352188,
#   'Carrot Commons',
#   43.6774845518262,
#   -79.35307562861175,
#   'Restaurant'),
#  ('M4K',
#   'East Toronto',
#   'The Danforth West, Riverdale',
#   43.6795571,
#   -79.352188,
#   'IL FORNELLO on Danforth',
#   43.67860392856738,
#   -79.34690364849348,
#   'Italian Restaurant'),
#  ('M4K',
#   'East Toronto',
#   'The Danforth West, Riverdale',
#   43.6795571,
#   -79.352188,
#   'Factory Girl',
#   43.67669287762859,
#   -79.35629876225282,
#   'American Restaurant'),
#  ('M4K',
#   'East Toronto',
#   'The Danforth West, Riverdale',
#   43.6795571,
#   -79.352188,
#   'Friendly Greek Restaurant',
#   43.67842791362434,
#   -79.34764181796815,
#   'Greek Restaurant'),
#  ('M4K',
#   'East Toronto',
#   'The Danforth West, Riverdale',
#   43.6795571,
#   -79.352188,
#   'LCBO',
#   43.676815838008714,
#   -79.35604671347544,
#   'Liquor Store'),
#  ('M4K',
#   'East Toronto',
#   'The Danforth West, Riverdale',
#   43.6795571,
#   -79.352188,
#   'Kitchen Stuff Plus',
#   43.67861256318158,
#   -79.34642163596001,
#   'Furniture / Home Store'),
#  ('M4K',
#   'East Toronto',
#   'The Danforth West, Riverdale',
#   43.6795571,
#   -79.352188,
#   'Starbucks',
#   43.678879,
#   -79.346357,
#   'Coffee Shop'),
#  ('M4L',
#   'East Toronto',
#   'India Bazaar, The Beaches West',
#   43.6689985,
#   -79.31557159999998,
#   'System Fitness',
#   43.667171452103204,
#   -79.31273345707406,
#   'Gym'),
#  ('M4L',
#   'East Toronto',
#   'India Bazaar, The Beaches West',
#   43.6689985,
#   -79.31557159999998,
#   'British Style Fish & Chips',
#   43.66872336908457,
#   -79.31713935234417,
#   'Fish & Chips Shop'),
#  ('M4L',
#   'East Toronto',
#   'India Bazaar, The Beaches West',
#   43.6689985,
#   -79.31557159999998,
#   "Brett's Ice Cream",
#   43.667222,
#   -79.312831,
#   'Ice Cream Shop'),
#  ('M4L',
#   'East Toronto',
#   'India Bazaar, The Beaches West',
#   43.6689985,
#   -79.31557159999998,
#   "The Burger's Priest",
#   43.666730640369295,
#   -79.31555614915459,
#   'Fast Food Restaurant'),
#  ('M4L',
#   'East Toronto',
#   'India Bazaar, The Beaches West',
#   43.6689985,
#   -79.31557159999998,
#   'O Sushi',
#   43.66668372330836,
#   -79.3166142781831,
#   'Sushi Restaurant'),
#  ('M4L',
#   'East Toronto',
#   'India Bazaar, The Beaches West',
#   43.6689985,
#   -79.31557159999998,
#   'Godspeed Brewery',
#   43.67262030152577,
#   -79.31922849103603,
#   'Brewery'),
#  ('M4L',
#   'East Toronto',
#   'India Bazaar, The Beaches West',
#   43.6689985,
#   -79.31557159999998,
#   'Woodbine Park',
#   43.66486036311473,
#   -79.31510925292969,
#   'Park'),
#  ('M4L',
#   'East Toronto',
#   'India Bazaar, The Beaches West',
#   43.6689985,
#   -79.31557159999998,
#   'LCBO',
#   43.66673150624233,
#   -79.31496605090986,
#   'Liquor Store'),
#  ('M4L',
#   'East Toronto',
#   'India Bazaar, The Beaches West',
#   43.6689985,
#   -79.31557159999998,
#   'Casa di Giorgio',
#   43.66664527559903,
#   -79.31520351125722,
#   'Italian Restaurant'),
#  ('M4L',
#   'East Toronto',
#   'India Bazaar, The Beaches West',
#   43.6689985,
#   -79.31557159999998,
#   'Pet Valu',
#   43.66697917950893,
#   -79.31466465565389,
#   'Pet Store'),
#  ('M4L',
#   'East Toronto',
#   'India Bazaar, The Beaches West',
#   43.6689985,
#   -79.31557159999998,
#   "Murphy's Law",
#   43.66731906186093,
#   -79.31265587607287,
#   'Pub'),
#  ('M4L',
#   'East Toronto',
#   'India Bazaar, The Beaches West',
#   43.6689985,
#   -79.31557159999998,
#   'The Tulip Steakhouse',
#   43.66634820248808,
#   -79.31685400996346,
#   'Steakhouse'),
#  ('M4L',
#   'East Toronto',
#   'India Bazaar, The Beaches West',
#   43.6689985,
#   -79.31557159999998,
#   'Burrito Bandidos',
#   43.66644546137557,
#   -79.31644740429473,
#   'Burrito Place'),
#  ('M4L',
#   'East Toronto',
#   'India Bazaar, The Beaches West',
#   43.6689985,
#   -79.31557159999998,
#   'Alliance Cinemas - The Beach',
#   43.666746976047506,
#   -79.31468500467349,
#   'Movie Theater'),
#  ('M4L',
#   'East Toronto',
#   'India Bazaar, The Beaches West',
#   43.6689985,
#   -79.31557159999998,
#   "Harvey's",
#   43.666528010542514,
#   -79.3151266656414,
#   'Restaurant'),
#  ('M4L',
#   'East Toronto',
#   'India Bazaar, The Beaches West',
#   43.6689985,
#   -79.31557159999998,
#   'Subway',
#   43.66605207373166,
#   -79.3169328912536,
#   'Sandwich Place'),
#  ('M4L',
#   'East Toronto',
#   'India Bazaar, The Beaches West',
#   43.6689985,
#   -79.31557159999998,
#   'KFC',
#   43.666624203184845,
#   -79.31591580156237,
#   'Fast Food Restaurant'),
#  ('M4L',
#   'East Toronto',
#   'India Bazaar, The Beaches West',
#   43.6689985,
#   -79.31557159999998,
#   'Queen & Coxwell',
#   43.66641257115568,
#   -79.31652545928955,
#   'Intersection'),
#  ('M4L',
#   'East Toronto',
#   'India Bazaar, The Beaches West',
#   43.6689985,
#   -79.31557159999998,
#   'Pizzaiolo',
#   43.66895319839045,
#   -79.31168339331794,
#   'Pizza Place'),
#  ('M4L',
#   'East Toronto',
#   'India Bazaar, The Beaches West',
#   43.6689985,
#   -79.31557159999998,
#   "Jody's Deli",
#   43.66894604610645,
#   -79.31163457258732,
#   'Sandwich Place'),
#  ('M4L',
#   'East Toronto',
#   'India Bazaar, The Beaches West',
#   43.6689985,
#   -79.31557159999998,
#   'Country Style',
#   43.667662,
#   -79.312006,
#   'Coffee Shop'),
#  ('M4L',
#   'East Toronto',
#   'India Bazaar, The Beaches West',
#   43.6689985,
#   -79.31557159999998,
#   'Supperworks',
#   43.66773719965272,
#   -79.310451509513,
#   'Food & Drink Shop'),
#  ('M4M',
#   'East Toronto',
#   'Studio District',
#   43.6595255,
#   -79.340923,
#   "Ed's Real Scoop",
#   43.660655832455014,
#   -79.3420187548006,
#   'Ice Cream Shop'),
#  ('M4M',
#   'East Toronto',
#   'Studio District',
#   43.6595255,
#   -79.340923,
#   'The Bone House',
#   43.66089376125636,
#   -79.3410974737743,
#   'Pet Store'),
#  ('M4M',
#   'East Toronto',
#   'Studio District',
#   43.6595255,
#   -79.340923,
#   'Queen Books',
#   43.6606506251737,
#   -79.34226723956905,
#   'Bookstore'),
#  ('M4M',
#   'East Toronto',
#   'Studio District',
#   43.6595255,
#   -79.340923,
#   'Hooked',
#   43.66040731524296,
#   -79.34325721641623,
#   'Fish Market'),
#  ('M4M',
#   'East Toronto',
#   'Studio District',
#   43.6595255,
#   -79.340923,
#   'Leslieville Pumps',
#   43.66089221309069,
#   -79.34062599380812,
#   'Sandwich Place'),
#  ('M4M',
#   'East Toronto',
#   'Studio District',
#   43.6595255,
#   -79.340923,
#   'Brick Street Breads',
#   43.66068453213004,
#   -79.3425013474948,
#   'Bakery'),
#  ('M4M',
#   'East Toronto',
#   'Studio District',
#   43.6595255,
#   -79.340923,
#   'Te Aro',
#   43.66137281675049,
#   -79.33857736283377,
#   'Coffee Shop'),
#  ('M4M',
#   'East Toronto',
#   'Studio District',
#   43.6595255,
#   -79.340923,
#   'WAYLABAR',
#   43.661234129782564,
#   -79.33959722763221,
#   'Gay Bar'),
#  ('M4M',
#   'East Toronto',
#   'Studio District',
#   43.6595255,
#   -79.340923,
#   'Leslieville',
#   43.66207024392778,
#   -79.33785619823739,
#   'Neighborhood'),
#  ('M4M',
#   'East Toronto',
#   'Studio District',
#   43.6595255,
#   -79.340923,
#   'Baldini',
#   43.661299966369135,
#   -79.33902686943661,
#   'Italian Restaurant'),
#  ('M4M',
#   'East Toronto',
#   'Studio District',
#   43.6595255,
#   -79.340923,
#   'Reliable Halibut and Chips',
#   43.660874,
#   -79.340938,
#   'Seafood Restaurant'),
#  ('M4M',
#   'East Toronto',
#   'Studio District',
#   43.6595255,
#   -79.340923,
#   'Mercury Espresso Bar',
#   43.66080615235188,
#   -79.34124064841119,
#   'Coffee Shop'),
#  ('M4M',
#   'East Toronto',
#   'Studio District',
#   43.6595255,
#   -79.340923,
#   'braised',
#   43.660451867292366,
#   -79.34334606916272,
#   'American Restaurant'),
#  ('M4M',
#   'East Toronto',
#   'Studio District',
#   43.6595255,
#   -79.340923,
#   'Leslieville Cheese Market',
#   43.66054639296253,
#   -79.3423024562941,
#   'Cheese Shop'),
#  ('M4M',
#   'East Toronto',
#   'Studio District',
#   43.6595255,
#   -79.340923,
#   'Purple Penguin Cafe',
#   43.660501150739734,
#   -79.34256490845178,
#   'Café'),
#  ('M4M',
#   'East Toronto',
#   'Studio District',
#   43.6595255,
#   -79.340923,
#   'Tabule',
#   43.65973096534363,
#   -79.3463408134466,
#   'Middle Eastern Restaurant'),
#  ('M4M',
#   'East Toronto',
#   'Studio District',
#   43.6595255,
#   -79.340923,
#   'eastside social',
#   43.661288901982886,
#   -79.33915476536174,
#   'Comfort Food Restaurant'),
#  ('M4M',
#   'East Toronto',
#   'Studio District',
#   43.6595255,
#   -79.340923,
#   'Wonder Pens',
#   43.662809067344405,
#   -79.34145159601191,
#   'Stationery Store'),
#  ('M4M',
#   'East Toronto',
#   'Studio District',
#   43.6595255,
#   -79.340923,
#   'Starbucks',
#   43.660742,
#   -79.342362,
#   'Coffee Shop'),
#  ('M4M',
#   'East Toronto',
#   'Studio District',
#   43.6595255,
#   -79.340923,
#   'Boxcar Social',
#   43.659722741351565,
#   -79.34687077721378,
#   'Café'),
#  ('M4M',
#   'East Toronto',
#   'Studio District',
#   43.6595255,
#   -79.340923,
#   'Chez Nous',
#   43.65964,
#   -79.3469,
#   'Wine Bar'),
#  ('M4M',
#   'East Toronto',
#   'Studio District',
#   43.6595255,
#   -79.340923,
#   'EAT BKK Thai Kitchen',
#   43.66045,
#   -79.343113,
#   'Thai Restaurant'),
#  ('M4M',
#   'East Toronto',
#   'Studio District',
#   43.6595255,
#   -79.340923,
#   'Avling Kitchen & Brewery',
#   43.661515,
#   -79.338117,
#   'Brewery'),
#  ('M4M',
#   'East Toronto',
#   'Studio District',
#   43.6595255,
#   -79.340923,
#   'District 28',
#   43.65517388160507,
#   -79.34059760137761,
#   'Coworking Space'),
#  ('M4M',
#   'East Toronto',
#   'Studio District',
#   43.6595255,
#   -79.340923,
#   'Bonjour Brioche',
#   43.65973440286799,
#   -79.34626614342186,
#   'Bakery'),
#  ('M4M',
#   'East Toronto',
#   'Studio District',
#   43.6595255,
#   -79.340923,
#   'Delica Kitchen',
#   43.66080581509536,
#   -79.34150197940215,
#   'Café'),
#  ('M4M',
#   'East Toronto',
#   'Studio District',
#   43.6595255,
#   -79.340923,
#   'Jimmie Simpson Park',
#   43.65922968838468,
#   -79.3450629597167,
#   'Park'),
#  ('M4M',
#   'East Toronto',
#   'Studio District',
#   43.6595255,
#   -79.340923,
#   'Sweat & Soda',
#   43.66185374187197,
#   -79.33619591158853,
#   'Café'),
#  ('M4M',
#   'East Toronto',
#   'Studio District',
#   43.6595255,
#   -79.340923,
#   'Spirit Loft Yoga',
#   43.66354815944136,
#   -79.3413327874046,
#   'Yoga Studio'),
#  ('M4M',
#   'East Toronto',
#   'Studio District',
#   43.6595255,
#   -79.340923,
#   'Barrio Cerveceria',
#   43.66043013260822,
#   -79.34350897486634,
#   'Latin American Restaurant'),
#  ('M4M',
#   'East Toronto',
#   'Studio District',
#   43.6595255,
#   -79.340923,
#   'Brooklyn Tavern',
#   43.66193697467491,
#   -79.33593786927155,
#   'American Restaurant'),
#  ('M4M',
#   'East Toronto',
#   'Studio District',
#   43.6595255,
#   -79.340923,
#   'The Thirsty Duck',
#   43.66113846977925,
#   -79.34010994796954,
#   'Gastropub'),
#  ('M4M',
#   'East Toronto',
#   'Studio District',
#   43.6595255,
#   -79.340923,
#   'Dwell Gym',
#   43.6634116374049,
#   -79.3411044597478,
#   'Gym / Fitness Center'),
#  ('M4M',
#   'East Toronto',
#   'Studio District',
#   43.6595255,
#   -79.340923,
#   'The Roy Public House',
#   43.660451849464096,
#   -79.34299382973943,
#   'Bar'),
#  ('M4M',
#   'East Toronto',
#   'Studio District',
#   43.6595255,
#   -79.340923,
#   '7-Eleven',
#   43.660897,
#   -79.340159,
#   'Convenience Store'),
#  ('M4M',
#   'East Toronto',
#   'Studio District',
#   43.6595255,
#   -79.340923,
#   'TD Canada Trust',
#   43.660659451666845,
#   -79.34277481866047,
#   'Bank'),
#  ('M4M',
#   'East Toronto',
#   'Studio District',
#   43.6595255,
#   -79.340923,
#   "Gale's Snack Bar",
#   43.658239,
#   -79.339077,
#   'Diner'),
#  ('M4M',
#   'East Toronto',
#   'Studio District',
#   43.6595255,
#   -79.340923,
#   'Good Neighbour',
#   43.6610004575794,
#   -79.34029809683763,
#   'Clothing Store'),
#  ('M4M',
#   'East Toronto',
#   'Studio District',
#   43.6595255,
#   -79.340923,
#   'Saulter Street Brewery',
#   43.6584115679406,
#   -79.34639217979787,
#   'Brewery'),
#  ('M4M',
#   'East Toronto',
#   'Studio District',
#   43.6595255,
#   -79.340923,
#   'McQueens Pub',
#   43.66148312783299,
#   -79.338072195258,
#   'Gastropub'),
#  ('M4M',
#   'East Toronto',
#   'Studio District',
#   43.6595255,
#   -79.340923,
#   'arts market',
#   43.659593,
#   -79.347009,
#   'Arts & Crafts Store'),
#  ('M4N',
#   'Central Toronto',
#   'Lawrence Park',
#   43.7280205,
#   -79.3887901,
#   'Lawrence Park Ravine',
#   43.72696303913755,
#   -79.39438246708775,
#   'Park'),
#  ('M4N',
#   'Central Toronto',
#   'Lawrence Park',
#   43.7280205,
#   -79.3887901,
#   'Zodiac Swim School',
#   43.72853205765438,
#   -79.3828602612317,
#   'Swim School'),
#  ('M4N',
#   'Central Toronto',
#   'Lawrence Park',
#   43.7280205,
#   -79.3887901,
#   'TTC Bus #162 - Lawrence-Donway',
#   43.72802605799448,
#   -79.38280527753858,
#   'Bus Line'),
#  ('M4P',
#   'Central Toronto',
#   'Davisville North',
#   43.7127511,
#   -79.3901975,
#   'Homeway Restaurant & Brunch',
#   43.71264120397444,
#   -79.39155655199944,
#   'Breakfast Spot'),
#  ('M4P',
#   'Central Toronto',
#   'Davisville North',
#   43.7127511,
#   -79.3901975,
#   'Sherwood Park',
#   43.71655100307589,
#   -79.38777567141624,
#   'Park'),
#  ('M4P',
#   'Central Toronto',
#   'Davisville North',
#   43.7127511,
#   -79.3901975,
#   'Summerhill Market North',
#   43.71549914910689,
#   -79.39288125988016,
#   'Food & Drink Shop'),
#  ('M4P',
#   'Central Toronto',
#   'Davisville North',
#   43.7127511,
#   -79.3901975,
#   'Winners',
#   43.71323606413252,
#   -79.3938728363979,
#   'Department Store'),
#  ('M4P',
#   'Central Toronto',
#   'Davisville North',
#   43.7127511,
#   -79.3901975,
#   'Best Western Roehampton Hotel & Suites',
#   43.7088783,
#   -79.3908798,
#   'Hotel'),
#  ('M4P',
#   'Central Toronto',
#   'Davisville North',
#   43.7127511,
#   -79.3901975,
#   'Subway',
#   43.7084743635371,
#   -79.39067425664052,
#   'Sandwich Place'),
#  ('M4P',
#   'Central Toronto',
#   'Davisville North',
#   43.7127511,
#   -79.3901975,
#   'Gym',
#   43.71312601210131,
#   -79.39353747528043,
#   'Gym'),
#  ('M4R',
#   'Central Toronto',
#   'North Toronto West',
#   43.7153834,
#   -79.40567840000001,
#   'Barreworks',
#   43.71407030751952,
#   -79.40010911522093,
#   'Yoga Studio'),
#  ('M4R',
#   'Central Toronto',
#   'North Toronto West',
#   43.7153834,
#   -79.40567840000001,
#   "Uncle Betty's Diner",
#   43.7144524368588,
#   -79.40009057656115,
#   'Diner'),
#  ('M4R',
#   'Central Toronto',
#   'North Toronto West',
#   43.7153834,
#   -79.40567840000001,
#   'Civello Salon',
#   43.71511093497453,
#   -79.40030409940266,
#   'Salon / Barbershop'),
#  ('M4R',
#   'Central Toronto',
#   'North Toronto West',
#   43.7153834,
#   -79.40567840000001,
#   'Sushi Shop',
#   43.713861,
#   -79.400093,
#   'Restaurant'),
#  ('M4R',
#   'Central Toronto',
#   'North Toronto West',
#   43.7153834,
#   -79.40567840000001,
#   "Tio's Urban Mexican",
#   43.71463,
#   -79.4,
#   'Mexican Restaurant'),
#  ('M4R',
#   'Central Toronto',
#   'North Toronto West',
#   43.7153834,
#   -79.40567840000001,
#   'Nailsense',
#   43.71746731916717,
#   -79.40065341489495,
#   'Spa'),
#  ('M4R',
#   'Central Toronto',
#   'North Toronto West',
#   43.7153834,
#   -79.40567840000001,
#   'lululemon',
#   43.7134783384539,
#   -79.4000817882245,
#   'Clothing Store'),
#  ('M4R',
#   'Central Toronto',
#   'North Toronto West',
#   43.7153834,
#   -79.40567840000001,
#   "C'est Bon",
#   43.71678474928588,
#   -79.40040634837081,
#   'Chinese Restaurant'),
#  ('M4R',
#   'Central Toronto',
#   'North Toronto West',
#   43.7153834,
#   -79.40567840000001,
#   'Dufflet Pastries',
#   43.71572948229811,
#   -79.40028336157728,
#   'Dessert Shop'),
#  ('M4R',
#   'Central Toronto',
#   'North Toronto West',
#   43.7153834,
#   -79.40567840000001,
#   'Starbucks',
#   43.71559,
#   -79.40045,
#   'Coffee Shop'),
#  ('M4R',
#   'Central Toronto',
#   'North Toronto West',
#   43.7153834,
#   -79.40567840000001,
#   'A&W',
#   43.715149,
#   -79.399944,
#   'Fast Food Restaurant'),
#  ('M4R',
#   'Central Toronto',
#   'North Toronto West',
#   43.7153834,
#   -79.40567840000001,
#   'Tim Hortons',
#   43.71489400011398,
#   -79.39977586269379,
#   'Coffee Shop'),
#  ('M4R',
#   'Central Toronto',
#   'North Toronto West',
#   43.7153834,
#   -79.40567840000001,
#   'GAP',
#   43.71544977487359,
#   -79.40008916661074,
#   'Clothing Store'),
#  ('M4R',
#   'Central Toronto',
#   'North Toronto West',
#   43.7153834,
#   -79.40567840000001,
#   'Sporting Life',
#   43.71627717160474,
#   -79.40024796918705,
#   'Sporting Goods Shop'),
#  ('M4R',
#   'Central Toronto',
#   'North Toronto West',
#   43.7153834,
#   -79.40567840000001,
#   'Second Cup',
#   43.714583000256965,
#   -79.40011973797179,
#   'Café'),
#  ('M4R',
#   'Central Toronto',
#   'North Toronto West',
#   43.7153834,
#   -79.40567840000001,
#   'St. Clements - Yonge Parkette',
#   43.71206179547874,
#   -79.40425523454469,
#   'Park'),
#  ('M4R',
#   'Central Toronto',
#   'North Toronto West',
#   43.7153834,
#   -79.40567840000001,
#   'Roots',
#   43.716193862387414,
#   -79.40066099166876,
#   'Clothing Store'),
#  ('M4R',
#   'Central Toronto',
#   'North Toronto West',
#   43.7153834,
#   -79.40567840000001,
#   'The Captain’s Boil',
#   43.715789,
#   -79.400187,
#   'Seafood Restaurant'),
#  ('M4R',
#   'Central Toronto',
#   'North Toronto West',
#   43.7153834,
#   -79.40567840000001,
#   'Drake General Store',
#   43.714712809782114,
#   -79.40015650911188,
#   'Gift Shop'),
#  ('M4R',
#   'Central Toronto',
#   'North Toronto West',
#   43.7153834,
#   -79.40567840000001,
#   'Pet Valu',
#   43.71412602510993,
#   -79.39997509672807,
#   'Pet Store'),
#  ('M4R',
#   'Central Toronto',
#   'North Toronto West',
#   43.7153834,
#   -79.40567840000001,
#   'Degrees Kitchen Store',
#   43.71430705492837,
#   -79.3998816417247,
#   'Furniture / Home Store'),
#  ('M4R',
#   'Central Toronto',
#   'North Toronto West',
#   43.7153834,
#   -79.40567840000001,
#   'GAP',
#   43.714009,
#   -79.399959,
#   'Clothing Store'),
#  ('M4R',
#   'Central Toronto',
#   'North Toronto West',
#   43.7153834,
#   -79.40567840000001,
#   'the bagel house',
#   43.714004,
#   -79.399953,
#   'Bagel Shop'),
#  ('M4R',
#   'Central Toronto',
#   'North Toronto West',
#   43.7153834,
#   -79.40567840000001,
#   "Summer's Best Fruits & Flowers",
#   43.713767,
#   -79.39987,
#   'Grocery Store'),
#  ('M4S',
#   'Central Toronto',
#   'Davisville',
#   43.7043244,
#   -79.3887901,
#   'Jules Cafe Patisserie',
#   43.70413799694304,
#   -79.38841260442167,
#   'Dessert Shop'),
#  ('M4S',
#   'Central Toronto',
#   'Davisville',
#   43.7043244,
#   -79.3887901,
#   'Thobors Boulangerie Patisserie Café',
#   43.704513877453266,
#   -79.38861602551758,
#   'Café'),
#  ('M4S',
#   'Central Toronto',
#   'Davisville',
#   43.7043244,
#   -79.3887901,
#   'Marigold Indian Bistro',
#   43.702880859375,
#   -79.38800811767578,
#   'Indian Restaurant'),
#  ('M4S',
#   'Central Toronto',
#   'Davisville',
#   43.7043244,
#   -79.3887901,
#   'XO Gelato',
#   43.70517671239303,
#   -79.3887930388649,
#   'Dessert Shop'),
#  ('M4S',
#   'Central Toronto',
#   'Davisville',
#   43.7043244,
#   -79.3887901,
#   'Viva Napoli',
#   43.70575225315343,
#   -79.38912464296774,
#   'Pizza Place'),
#  ('M4S',
#   'Central Toronto',
#   'Davisville',
#   43.7043244,
#   -79.3887901,
#   'Zee Grill',
#   43.70498511291793,
#   -79.38847622354874,
#   'Seafood Restaurant'),
#  ('M4S',
#   'Central Toronto',
#   'Davisville',
#   43.7043244,
#   -79.3887901,
#   'Starbucks',
#   43.705923,
#   -79.389548,
#   'Coffee Shop'),
#  ('M4S',
#   'Central Toronto',
#   'Davisville',
#   43.7043244,
#   -79.3887901,
#   'Sakae Sushi',
#   43.70494407149989,
#   -79.38870408604551,
#   'Sushi Restaurant'),
#  ('M4S',
#   'Central Toronto',
#   'Davisville',
#   43.7043244,
#   -79.3887901,
#   'Florentia Ristorante',
#   43.703594,
#   -79.3879846,
#   'Italian Restaurant'),
#  ('M4S',
#   'Central Toronto',
#   'Davisville',
#   43.7043244,
#   -79.3887901,
#   'Positano',
#   43.704558,
#   -79.38863854,
#   'Italian Restaurant'),
#  ('M4S',
#   'Central Toronto',
#   'Davisville',
#   43.7043244,
#   -79.3887901,
#   'June Rowlands Park',
#   43.70051698238234,
#   -79.38918866607341,
#   'Park'),
#  ('M4S',
#   'Central Toronto',
#   'Davisville',
#   43.7043244,
#   -79.3887901,
#   'Flaky Tart',
#   43.70653850357435,
#   -79.38961139953942,
#   'Dessert Shop'),
#  ('M4S',
#   'Central Toronto',
#   'Davisville',
#   43.7043244,
#   -79.3887901,
#   'Thai Spicy House',
#   43.7019616162845,
#   -79.3875129672506,
#   'Thai Restaurant'),
#  ('M4S',
#   'Central Toronto',
#   'Davisville',
#   43.7043244,
#   -79.3887901,
#   'Bread and Butter',
#   43.70158248227423,
#   -79.3873587869354,
#   'Sandwich Place'),
#  ('M4S',
#   'Central Toronto',
#   'Davisville',
#   43.7043244,
#   -79.3887901,
#   'GoodLife Fitness Toronto Mount Pleasant and Davisville',
#   43.700802,
#   -79.386417,
#   'Gym'),
#  ('M4S',
#   'Central Toronto',
#   'Davisville',
#   43.7043244,
#   -79.3887901,
#   'Crossfit Metric',
#   43.70747956557104,
#   -79.38985687683696,
#   'Gym'),
#  ('M4S',
#   'Central Toronto',
#   'Davisville',
#   43.7043244,
#   -79.3887901,
#   'Hokkaido Sushi',
#   43.708081718364554,
#   -79.38999467246003,
#   'Sushi Restaurant'),
#  ('M4S',
#   'Central Toronto',
#   'Davisville',
#   43.7043244,
#   -79.3887901,
#   'Mastermind Toys',
#   43.704839243420075,
#   -79.38854629838522,
#   'Toy / Game Store'),
#  ('M4S',
#   'Central Toronto',
#   'Davisville',
#   43.7043244,
#   -79.3887901,
#   'Granite Brewery',
#   43.70799119535042,
#   -79.38994275728216,
#   'Brewery'),
#  ('M4S',
#   'Central Toronto',
#   'Davisville',
#   43.7043244,
#   -79.3887901,
#   "Hazel's Diner",
#   43.70210267511542,
#   -79.3876176468172,
#   'Diner'),
#  ('M4S',
#   'Central Toronto',
#   'Davisville',
#   43.7043244,
#   -79.3887901,
#   'souvlaki express',
#   43.70737794652891,
#   -79.38984793934696,
#   'Greek Restaurant'),
#  ('M4S',
#   'Central Toronto',
#   'Davisville',
#   43.7043244,
#   -79.3887901,
#   'Second Cup',
#   43.704344001380505,
#   -79.38865888961692,
#   'Coffee Shop'),
#  ('M4S',
#   'Central Toronto',
#   'Davisville',
#   43.7043244,
#   -79.3887901,
#   'Petro-Canada',
#   43.70226903889355,
#   -79.38795536756516,
#   'Gas Station'),
#  ('M4S',
#   'Central Toronto',
#   'Davisville',
#   43.7043244,
#   -79.3887901,
#   "Apple Tree Farmer's Market",
#   43.70032613903132,
#   -79.38976045544334,
#   'Farmers Market'),
#  ('M4S',
#   'Central Toronto',
#   'Davisville',
#   43.7043244,
#   -79.3887901,
#   'Starving Artist',
#   43.701538,
#   -79.38724,
#   'Restaurant'),
#  ('M4S',
#   'Central Toronto',
#   'Davisville',
#   43.7043244,
#   -79.3887901,
#   'Meow Cat Cafe',
#   43.702927,
#   -79.38819,
#   'Café'),
#  ('M4S',
#   'Central Toronto',
#   'Davisville',
#   43.7043244,
#   -79.3887901,
#   "Marcheleo's Gourmet Marketplace",
#   43.70804065392919,
#   -79.39219480282117,
#   'Gourmet Shop'),
#  ('M4S',
#   'Central Toronto',
#   'Davisville',
#   43.7043244,
#   -79.3887901,
#   'Subway',
#   43.70176337400996,
#   -79.38780495416756,
#   'Sandwich Place'),
#  ('M4S',
#   'Central Toronto',
#   'Davisville',
#   43.7043244,
#   -79.3887901,
#   'Pizza Pizza',
#   43.70613821755869,
#   -79.38929246805056,
#   'Pizza Place'),
#  ('M4S',
#   'Central Toronto',
#   'Davisville',
#   43.7043244,
#   -79.3887901,
#   'Shoppers Drug Mart',
#   43.707806,
#   -79.389893,
#   'Pharmacy'),
#  ('M4S',
#   'Central Toronto',
#   'Davisville',
#   43.7043244,
#   -79.3887901,
#   'Subway',
#   43.7084743635371,
#   -79.39067425664052,
#   'Sandwich Place'),
#  ('M4S',
#   'Central Toronto',
#   'Davisville',
#   43.7043244,
#   -79.3887901,
#   'Rosedale Kennedy Flowers',
#   43.704291008015225,
#   -79.38873233163676,
#   'Flower Shop'),
#  ('M4S',
#   'Central Toronto',
#   'Davisville',
#   43.7043244,
#   -79.3887901,
#   'The Belsize Public House',
#   43.702533638111404,
#   -79.3877380008186,
#   'New American Restaurant'),
#  ('M4S',
#   'Central Toronto',
#   'Davisville',
#   43.7043244,
#   -79.3887901,
#   'Kidnasium',
#   43.706938885972804,
#   -79.3895295409309,
#   'Indoor Play Area'),
#  ('M4S',
#   'Central Toronto',
#   'Davisville',
#   43.7043244,
#   -79.3887901,
#   'Seven 44',
#   43.707187025383305,
#   -79.38973979514955,
#   'Bar'),
#  ('M4S',
#   'Central Toronto',
#   'Davisville',
#   43.7043244,
#   -79.3887901,
#   'Pizzaiolo',
#   43.70730077620926,
#   -79.38982962163259,
#   'Pizza Place'),
#  ('M4S',
#   'Central Toronto',
#   'Davisville',
#   43.7043244,
#   -79.3887901,
#   'Pizza Nova',
#   43.70752400823691,
#   -79.3898628311206,
#   'Pizza Place'),
#  ('M4S',
#   'Central Toronto',
#   'Davisville',
#   43.7043244,
#   -79.3887901,
#   'Provocative Pizza Series',
#   43.708293114505096,
#   -79.38954603484376,
#   'Pizza Place'),
#  ('M4T',
#   'Central Toronto',
#   'Moore Park, Summerhill East',
#   43.6895743,
#   -79.38315990000001,
#   'Loring-Wyle Parkette',
#   43.690270427217385,
#   -79.3834375880377,
#   'Park'),
#  ('M4T',
#   'Central Toronto',
#   'Moore Park, Summerhill East',
#   43.6895743,
#   -79.38315990000001,
#   'Reds',
#   43.6928156790476,
#   -79.38450425856912,
#   'Restaurant'),
#  ('M4T',
#   'Central Toronto',
#   'Moore Park, Summerhill East',
#   43.6895743,
#   -79.38315990000001,
#   'Moorevale Park',
#   43.693609879336925,
#   -79.38346507970056,
#   'Playground'),
#  ('M4V',
#   'Central Toronto',
#   'Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park',
#   43.68641229999999,
#   -79.4000493,
#   'The Market By Longo’s',
#   43.686711,
#   -79.399536,
#   'Supermarket'),
#  ('M4V',
#   'Central Toronto',
#   'Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park',
#   43.68641229999999,
#   -79.4000493,
#   'LCBO',
#   43.686990631074885,
#   -79.39923810519545,
#   'Liquor Store'),
#  ('M4V',
#   'Central Toronto',
#   'Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park',
#   43.68641229999999,
#   -79.4000493,
#   'Daeco Sushi',
#   43.68783769992881,
#   -79.39565249242683,
#   'Sushi Restaurant'),
#  ('M4V',
#   'Central Toronto',
#   'Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park',
#   43.68641229999999,
#   -79.4000493,
#   'Mary Be Kitchen',
#   43.687708,
#   -79.395062,
#   'Restaurant'),
#  ('M4V',
#   'Central Toronto',
#   'Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park',
#   43.68641229999999,
#   -79.4000493,
#   'Union Social Eatery',
#   43.68789522205706,
#   -79.39491559605742,
#   'American Restaurant'),
#  ('M4V',
#   'Central Toronto',
#   'Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park',
#   43.68641229999999,
#   -79.4000493,
#   'Starbucks',
#   43.686756,
#   -79.398292,
#   'Coffee Shop'),
#  ('M4V',
#   'Central Toronto',
#   'Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park',
#   43.68641229999999,
#   -79.4000493,
#   'Tim Hortons',
#   43.687682,
#   -79.39684,
#   'Coffee Shop'),
#  ('M4V',
#   'Central Toronto',
#   'Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park',
#   43.68641229999999,
#   -79.4000493,
#   "Fionn MacCool's",
#   43.68792137317272,
#   -79.39478325313542,
#   'Pub'),
#  ('M4V',
#   'Central Toronto',
#   'Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park',
#   43.68641229999999,
#   -79.4000493,
#   'RBC Royal Bank',
#   43.68806164142636,
#   -79.39500079795525,
#   'Bank'),
#  ('M4V',
#   'Central Toronto',
#   'Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park',
#   43.68641229999999,
#   -79.4000493,
#   'Raiders E-Sports Centre',
#   43.687682915990386,
#   -79.39594439646025,
#   'Sports Bar'),
#  ('M4V',
#   'Central Toronto',
#   'Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park',
#   43.68641229999999,
#   -79.4000493,
#   'Popeyes Louisiana Kitchen',
#   43.6893,
#   -79.395302,
#   'Fried Chicken Joint'),
#  ('M4V',
#   'Central Toronto',
#   'Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park',
#   43.68641229999999,
#   -79.4000493,
#   'Scallywags',
#   43.687981749962695,
#   -79.39467568457059,
#   'Pub'),
#  ('M4V',
#   'Central Toronto',
#   'Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park',
#   43.68641229999999,
#   -79.4000493,
#   'Sprout',
#   43.687995609133544,
#   -79.39465149552744,
#   'Vietnamese Restaurant'),
#  ('M4V',
#   'Central Toronto',
#   'Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park',
#   43.68641229999999,
#   -79.4000493,
#   'Pizzaiolo',
#   43.68799051263145,
#   -79.39463424218918,
#   'Pizza Place'),
#  ('M4V',
#   'Central Toronto',
#   'Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park',
#   43.68641229999999,
#   -79.4000493,
#   'TTC Stop #',
#   43.6858256,
#   -79.40498099,
#   'Light Rail Station'),
#  ('M4V',
#   'Central Toronto',
#   'Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park',
#   43.68641229999999,
#   -79.4000493,
#   "Kiva's",
#   43.687983764255456,
#   -79.39471505267664,
#   'Bagel Shop'),
#  ('M4W',
#   'Downtown Toronto',
#   'Rosedale',
#   43.6795626,
#   -79.37752940000001,
#   'Rosedale Park',
#   43.68232820227814,
#   -79.37893434347683,
#   'Playground'),
#  ('M4W',
#   'Downtown Toronto',
#   'Rosedale',
#   43.6795626,
#   -79.37752940000001,
#   'Whitney Park',
#   43.68203573063681,
#   -79.37378835021306,
#   'Park'),
#  ('M4W',
#   'Downtown Toronto',
#   'Rosedale',
#   43.6795626,
#   -79.37752940000001,
#   'Alex Murray Parkette',
#   43.678300240478954,
#   -79.38277328698108,
#   'Park'),
#  ('M4W',
#   'Downtown Toronto',
#   'Rosedale',
#   43.6795626,
#   -79.37752940000001,
#   "Milkman's Lane",
#   43.676352068015554,
#   -79.37384239440172,
#   'Trail'),
#  ('M4X',
#   'Downtown Toronto',
#   'St. James Town, Cabbagetown',
#   43.667967,
#   -79.3676753,
#   'Cranberries',
#   43.6678427705951,
#   -79.36940687874281,
#   'Diner'),
#  ('M4X',
#   'Downtown Toronto',
#   'St. James Town, Cabbagetown',
#   43.667967,
#   -79.3676753,
#   "F'Amelia",
#   43.66753590663226,
#   -79.36861331485827,
#   'Italian Restaurant'),
#  ('M4X',
#   'Downtown Toronto',
#   'St. James Town, Cabbagetown',
#   43.667967,
#   -79.3676753,
#   'Butter Chicken Factory',
#   43.66707247004843,
#   -79.36918422958169,
#   'Indian Restaurant'),
#  ('M4X',
#   'Downtown Toronto',
#   'St. James Town, Cabbagetown',
#   43.667967,
#   -79.3676753,
#   'Kingyo Toronto',
#   43.66589495808371,
#   -79.36841520638596,
#   'Japanese Restaurant'),
#  ('M4X',
#   'Downtown Toronto',
#   'St. James Town, Cabbagetown',
#   43.667967,
#   -79.3676753,
#   'Murgatroid',
#   43.66738149016019,
#   -79.36931129229457,
#   'Restaurant'),
#  ('M4X',
#   'Downtown Toronto',
#   'St. James Town, Cabbagetown',
#   43.667967,
#   -79.3676753,
#   'Merryberry Cafe + Bistro',
#   43.66663020301851,
#   -79.36879184199822,
#   'Café'),
#  ('M4X',
#   'Downtown Toronto',
#   'St. James Town, Cabbagetown',
#   43.667967,
#   -79.3676753,
#   'Cabbagetown Brew',
#   43.66692279890784,
#   -79.36928929560437,
#   'Café'),
#  ('M4X',
#   'Downtown Toronto',
#   'St. James Town, Cabbagetown',
#   43.667967,
#   -79.3676753,
#   'Absolute Bakery & Café',
#   43.667469462461995,
#   -79.36927654747196,
#   'Bakery'),
#  ('M4X',
#   'Downtown Toronto',
#   'St. James Town, Cabbagetown',
#   43.667967,
#   -79.3676753,
#   'Fair Trade Jewellery Co.',
#   43.6653480241165,
#   -79.36836240366654,
#   'Jewelry Store'),
#  ('M4X',
#   'Downtown Toronto',
#   'St. James Town, Cabbagetown',
#   43.667967,
#   -79.3676753,
#   'Toronto Dance Theatre',
#   43.66623230619368,
#   -79.36707506629983,
#   'General Entertainment'),
#  ('M4X',
#   'Downtown Toronto',
#   'St. James Town, Cabbagetown',
#   43.667967,
#   -79.3676753,
#   'St. Jamestown Delicatessen',
#   43.66581142395609,
#   -79.36864825640076,
#   'Butcher'),
#  ('M4X',
#   'Downtown Toronto',
#   'St. James Town, Cabbagetown',
#   43.667967,
#   -79.3676753,
#   'Pet Valu',
#   43.66420501339666,
#   -79.36846012382637,
#   'Pet Store'),
#  ('M4X',
#   'Downtown Toronto',
#   'St. James Town, Cabbagetown',
#   43.667967,
#   -79.3676753,
#   'Stout Irish Pub',
#   43.66389071833622,
#   -79.3690300810636,
#   'Pub'),
#  ('M4X',
#   'Downtown Toronto',
#   'St. James Town, Cabbagetown',
#   43.667967,
#   -79.3676753,
#   'House on Parliament',
#   43.663645704974314,
#   -79.36785378722945,
#   'Gastropub'),
#  ('M4X',
#   'Downtown Toronto',
#   'St. James Town, Cabbagetown',
#   43.667967,
#   -79.3676753,
#   'Mr. Jerk',
#   43.66732847256732,
#   -79.37338943621165,
#   'Caribbean Restaurant'),
#  ('M4X',
#   'Downtown Toronto',
#   'St. James Town, Cabbagetown',
#   43.667967,
#   -79.3676753,
#   'Kanpai Snack Bar',
#   43.664330935948634,
#   -79.36806503124257,
#   'Taiwanese Restaurant'),
#  ('M4X',
#   'Downtown Toronto',
#   'St. James Town, Cabbagetown',
#   43.667967,
#   -79.3676753,
#   'Labour Of Love',
#   43.663907,
#   -79.368822,
#   'Gift Shop'),
#  ('M4X',
#   'Downtown Toronto',
#   'St. James Town, Cabbagetown',
#   43.667967,
#   -79.3676753,
#   'The Epicure Shop',
#   43.663964860964924,
#   -79.36779540886938,
#   'Deli / Bodega'),
#  ('M4X',
#   'Downtown Toronto',
#   'St. James Town, Cabbagetown',
#   43.667967,
#   -79.3676753,
#   'Wellesley Park',
#   43.6696487958367,
#   -79.3621551990509,
#   'Park'),
#  ('M4X',
#   'Downtown Toronto',
#   'St. James Town, Cabbagetown',
#   43.667967,
#   -79.3676753,
#   'The Pear Tree',
#   43.664904018134834,
#   -79.36824639094671,
#   'Restaurant'),
#  ('M4X',
#   'Downtown Toronto',
#   'St. James Town, Cabbagetown',
#   43.667967,
#   -79.3676753,
#   'Sunny Green Vegetable and Fruit',
#   43.667555388483756,
#   -79.3724347693053,
#   'Market'),
#  ('M4X',
#   'Downtown Toronto',
#   'St. James Town, Cabbagetown',
#   43.667967,
#   -79.3676753,
#   'TD Canada Trust',
#   43.66465469253796,
#   -79.36788707971579,
#   'Bank'),
#  ('M4X',
#   'Downtown Toronto',
#   'St. James Town, Cabbagetown',
#   43.667967,
#   -79.3676753,
#   'Hey Lucy',
#   43.66407509923825,
#   -79.36865505824356,
#   'Italian Restaurant'),
#  ('M4X',
#   'Downtown Toronto',
#   'St. James Town, Cabbagetown',
#   43.667967,
#   -79.3676753,
#   'Thai Room - Cabbagetown',
#   43.6641587260231,
#   -79.36818872980979,
#   'Thai Restaurant'),
#  ('M4X',
#   'Downtown Toronto',
#   'St. James Town, Cabbagetown',
#   43.667967,
#   -79.3676753,
#   'Jetfuel Coffee',
#   43.66529519392083,
#   -79.3683345416816,
#   'Coffee Shop'),
#  ('M4X',
#   'Downtown Toronto',
#   'St. James Town, Cabbagetown',
#   43.667967,
#   -79.3676753,
#   'LCBO',
#   43.665585593088366,
#   -79.36853050840249,
#   'Liquor Store'),
#  ('M4X',
#   'Downtown Toronto',
#   'St. James Town, Cabbagetown',
#   43.667967,
#   -79.3676753,
#   'Winchester Park',
#   43.66623107575282,
#   -79.3716312803108,
#   'Playground'),
#  ('M4X',
#   'Downtown Toronto',
#   'St. James Town, Cabbagetown',
#   43.667967,
#   -79.3676753,
#   'Daniel et Daniel Event Creation & Catering',
#   43.6643837,
#   -79.3683282,
#   'Bakery'),
#  ('M4X',
#   'Downtown Toronto',
#   'St. James Town, Cabbagetown',
#   43.667967,
#   -79.3676753,
#   'Tim Hortons',
#   43.66716925802294,
#   -79.36884865164751,
#   'Coffee Shop'),
#  ('M4X',
#   'Downtown Toronto',
#   'St. James Town, Cabbagetown',
#   43.667967,
#   -79.3676753,
#   'The Beer Store',
#   43.6664079,
#   -79.368833,
#   'Beer Store'),
#  ('M4X',
#   'Downtown Toronto',
#   'St. James Town, Cabbagetown',
#   43.667967,
#   -79.3676753,
#   'Subway',
#   43.66564329610601,
#   -79.3683001523662,
#   'Sandwich Place'),
#  ('M4X',
#   'Downtown Toronto',
#   'St. James Town, Cabbagetown',
#   43.667967,
#   -79.3676753,
#   'Pizza Pizza',
#   43.667178738521734,
#   -79.36966873777858,
#   'Pizza Place'),
#  ('M4X',
#   'Downtown Toronto',
#   'St. James Town, Cabbagetown',
#   43.667967,
#   -79.3676753,
#   'Tim Hortons',
#   43.665785871990316,
#   -79.36828404664993,
#   'Coffee Shop'),
#  ('M4X',
#   'Downtown Toronto',
#   'St. James Town, Cabbagetown',
#   43.667967,
#   -79.3676753,
#   'The Flying Beaver Pubaret',
#   43.664828798875426,
#   -79.36829203718695,
#   'Pub'),
#  ('M4X',
#   'Downtown Toronto',
#   'St. James Town, Cabbagetown',
#   43.667967,
#   -79.3676753,
#   "Johnny G's",
#   43.66456495893274,
#   -79.36806027251208,
#   'Breakfast Spot'),
#  ('M4X',
#   'Downtown Toronto',
#   'St. James Town, Cabbagetown',
#   43.667967,
#   -79.3676753,
#   'China Gourmet',
#   43.6641802410051,
#   -79.36835925727236,
#   'Chinese Restaurant'),
#  ('M4X',
#   'Downtown Toronto',
#   'St. James Town, Cabbagetown',
#   43.667967,
#   -79.3676753,
#   'Pizza Pizza',
#   43.66809038080825,
#   -79.37027389227195,
#   'Pizza Place'),
#  ('M4X',
#   'Downtown Toronto',
#   'St. James Town, Cabbagetown',
#   43.667967,
#   -79.3676753,
#   'Shoppers Drug Mart',
#   43.663998,
#   -79.36783,
#   'Pharmacy'),
#  ('M4X',
#   'Downtown Toronto',
#   'St. James Town, Cabbagetown',
#   43.667967,
#   -79.3676753,
#   'El Charro',
#   43.667606,
#   -79.36949,
#   'Restaurant'),
#  ('M4X',
#   'Downtown Toronto',
#   'St. James Town, Cabbagetown',
#   43.667967,
#   -79.3676753,
#   'Tim Hortons / Esso',
#   43.66712972601009,
#   -79.37066407870991,
#   'Coffee Shop'),
#  ('M4X',
#   'Downtown Toronto',
#   'St. James Town, Cabbagetown',
#   43.667967,
#   -79.3676753,
#   'No Frills',
#   43.663515,
#   -79.367166,
#   'Grocery Store'),
#  ('M4X',
#   'Downtown Toronto',
#   'St. James Town, Cabbagetown',
#   43.667967,
#   -79.3676753,
#   'Park Snacks',
#   43.66697911709206,
#   -79.36311542987823,
#   'Snack Place'),
#  ('M4X',
#   'Downtown Toronto',
#   'St. James Town, Cabbagetown',
#   43.667967,
#   -79.3676753,
#   'Beckers',
#   43.66745509366002,
#   -79.3732981061779,
#   'Convenience Store'),
#  ('M4Y',
#   'Downtown Toronto',
#   'Church and Wellesley',
#   43.6658599,
#   -79.38315990000001,
#   'Storm Crow Manor',
#   43.66683985695023,
#   -79.38159278029707,
#   'Theme Restaurant'),
#  ('M4Y',
#   'Downtown Toronto',
#   'Church and Wellesley',
#   43.6658599,
#   -79.38315990000001,
#   'DanceLifeX Centre',
#   43.66695583448771,
#   -79.3852972984314,
#   'Dance Studio'),
#  ('M4Y',
#   'Downtown Toronto',
#   'Church and Wellesley',
#   43.6658599,
#   -79.38315990000001,
#   'Como En Casa',
#   43.66516,
#   -79.384796,
#   'Mexican Restaurant'),
#  ('M4Y',
#   'Downtown Toronto',
#   'Church and Wellesley',
#   43.6658599,
#   -79.38315990000001,
#   'The Alley',
#   43.66592244798498,
#   -79.38556672752236,
#   'Bubble Tea Shop'),
#  ('M4Y',
#   'Downtown Toronto',
#   'Church and Wellesley',
#   43.6658599,
#   -79.38315990000001,
#   'Wickson Social',
#   43.66590450775969,
#   -79.38571974166427,
#   'Gastropub'),
#  ('M4Y',
#   'Downtown Toronto',
#   'Church and Wellesley',
#   43.6658599,
#   -79.38315990000001,
#   'Fabarnak',
#   43.66637677585409,
#   -79.38096396850409,
#   'Restaurant'),
#  ('M4Y',
#   'Downtown Toronto',
#   'Church and Wellesley',
#   43.6658599,
#   -79.38315990000001,
#   'Bar Volo',
#   43.66546184849369,
#   -79.38569158315659,
#   'Beer Bar'),
#  ('M4Y',
#   'Downtown Toronto',
#   'Church and Wellesley',
#   43.6658599,
#   -79.38315990000001,
#   'Smith',
#   43.66692666745884,
#   -79.38142135954267,
#   'Breakfast Spot'),
#  ('M4Y',
#   'Downtown Toronto',
#   'Church and Wellesley',
#   43.6658599,
#   -79.38315990000001,
#   'Barbara Hall Park',
#   43.66687857011423,
#   -79.38106777601625,
#   'Park'),
#  ('M4Y',
#   'Downtown Toronto',
#   'Church and Wellesley',
#   43.6658599,
#   -79.38315990000001,
#   'Sansotei Ramen 三草亭',
#   43.666734794517005,
#   -79.3853530009483,
#   'Ramen Restaurant'),
#  ('M4Y',
#   'Downtown Toronto',
#   'Church and Wellesley',
#   43.6658599,
#   -79.38315990000001,
#   "Dal Moro's Fresh Pasta To Go",
#   43.66664070494267,
#   -79.38540023837237,
#   'Italian Restaurant'),
#  ('M4Y',
#   'Downtown Toronto',
#   'Church and Wellesley',
#   43.6658599,
#   -79.38315990000001,
#   'Hero Certified Burgers',
#   43.66562403029978,
#   -79.38090430769088,
#   'Burger Joint'),
#  ('M4Y',
#   'Downtown Toronto',
#   'Church and Wellesley',
#   43.6658599,
#   -79.38315990000001,
#   "Ho's Team Barber Shop",
#   43.66563031656884,
#   -79.38135926650858,
#   'Salon / Barbershop'),
#  ('M4Y',
#   'Downtown Toronto',
#   'Church and Wellesley',
#   43.6658599,
#   -79.38315990000001,
#   'T-Swirl Crepe',
#   43.663452,
#   -79.384125,
#   'Creperie'),
#  ('M4Y',
#   'Downtown Toronto',
#   'Church and Wellesley',
#   43.6658599,
#   -79.38315990000001,
#   'Glad Day Bookshop',
#   43.66527119350875,
#   -79.38078512672504,
#   'Bookstore'),
#  ('M4Y',
#   'Downtown Toronto',
#   'Church and Wellesley',
#   43.6658599,
#   -79.38315990000001,
#   'FUEL+',
#   43.66439936324463,
#   -79.38042718414235,
#   'Juice Bar'),
#  ('M4Y',
#   'Downtown Toronto',
#   'Church and Wellesley',
#   43.6658599,
#   -79.38315990000001,
#   'Si Lom',
#   43.66501007731949,
#   -79.38068288199048,
#   'Thai Restaurant'),
#  ('M4Y',
#   'Downtown Toronto',
#   'Church and Wellesley',
#   43.6658599,
#   -79.38315990000001,
#   'Coach House Restaurant',
#   43.66499059853204,
#   -79.38481415727767,
#   'Diner'),
#  ('M4Y',
#   'Downtown Toronto',
#   'Church and Wellesley',
#   43.6658599,
#   -79.38315990000001,
#   'North of Brooklyn Pizzeria',
#   43.664383604568975,
#   -79.38037571983865,
#   'Pizza Place'),
#  ('M4Y',
#   'Downtown Toronto',
#   'Church and Wellesley',
#   43.6658599,
#   -79.38315990000001,
#   'Openmat Mixed Martial Arts',
#   43.666171607941095,
#   -79.3847667237342,
#   'Martial Arts Dojo'),
#  ('M4Y',
#   'Downtown Toronto',
#   'Church and Wellesley',
#   43.6658599,
#   -79.38315990000001,
#   'Piedmont Coffee Bar',
#   43.66828640594333,
#   -79.38252026711419,
#   'Coffee Shop'),
#  ('M4Y',
#   'Downtown Toronto',
#   'Church and Wellesley',
#   43.6658599,
#   -79.38315990000001,
#   'Tokyo Grill',
#   43.665085238149395,
#   -79.38470692554789,
#   'Japanese Restaurant'),
#  ('M4Y',
#   'Downtown Toronto',
#   'Church and Wellesley',
#   43.6658599,
#   -79.38315990000001,
#   'Sushi Garden',
#   43.66485840073255,
#   -79.38494112880176,
#   'Sushi Restaurant'),
#  ('M4Y',
#   'Downtown Toronto',
#   'Church and Wellesley',
#   43.6658599,
#   -79.38315990000001,
#   'Church Street Espresso',
#   43.66829221417146,
#   -79.38187727767004,
#   'Café'),
#  ('M4Y',
#   'Downtown Toronto',
#   'Church and Wellesley',
#   43.6658599,
#   -79.38315990000001,
#   'Toronto Hemp Company',
#   43.668419429320515,
#   -79.38584843598086,
#   'Smoke Shop'),
#  ('M4Y',
#   'Downtown Toronto',
#   'Church and Wellesley',
#   43.6658599,
#   -79.38315990000001,
#   "Curry's Art Store Ltd.",
#   43.66283810530193,
#   -79.38373201352064,
#   'Arts & Crafts Store'),
#  ('M4Y',
#   'Downtown Toronto',
#   'Church and Wellesley',
#   43.6658599,
#   -79.38315990000001,
#   '401 Games',
#   43.663623277853254,
#   -79.3840374323983,
#   'Hobby Shop'),
#  ('M4Y',
#   'Downtown Toronto',
#   'Church and Wellesley',
#   43.6658599,
#   -79.38315990000001,
#   'Kothur Indian Cuisine',
#   43.66787229558206,
#   -79.38565911153148,
#   'Indian Restaurant'),
#  ('M4Y',
#   'Downtown Toronto',
#   'Church and Wellesley',
#   43.6658599,
#   -79.38315990000001,
#   'Churchmouse & Firkin',
#   43.66463217328346,
#   -79.38040612389896,
#   'Pub'),
#  ('M4Y',
#   'Downtown Toronto',
#   'Church and Wellesley',
#   43.6658599,
#   -79.38315990000001,
#   "The Men's Room",
#   43.664445596525944,
#   -79.38006704821788,
#   "Men's Store"),
#  ('M4Y',
#   'Downtown Toronto',
#   'Church and Wellesley',
#   43.6658599,
#   -79.38315990000001,
#   'Black Eagle',
#   43.66408473971554,
#   -79.38009823456886,
#   'Gay Bar'),
#  ('M4Y',
#   'Downtown Toronto',
#   'Church and Wellesley',
#   43.6658599,
#   -79.38315990000001,
#   'Burrito Bandidos',
#   43.662962178169344,
#   -79.38395554190546,
#   'Burrito Place'),
#  ('M4Y',
#   'Downtown Toronto',
#   'Church and Wellesley',
#   43.6658599,
#   -79.38315990000001,
#   'St. Louis Bar and Grill',
#   43.66385323730235,
#   -79.38418742909323,
#   'Wings Joint'),
#  ('M4Y',
#   'Downtown Toronto',
#   'Church and Wellesley',
#   43.6658599,
#   -79.38315990000001,
#   'The Keg Steakhouse + Bar',
#   43.66675618397813,
#   -79.37830241801962,
#   'Steakhouse'),
#  ('M4Y',
#   'Downtown Toronto',
#   'Church and Wellesley',
#   43.6658599,
#   -79.38315990000001,
#   'Central YMCA',
#   43.663083310067655,
#   -79.38502493214878,
#   'Distribution Center'),
#  ('M4Y',
#   'Downtown Toronto',
#   'Church and Wellesley',
#   43.6658599,
#   -79.38315990000001,
#   'Bikram Yoga Yonge',
# ...
#   'Downtown Toronto',
#   'Toronto Dominion Centre, Design Exchange',
#   43.6471768,
#   -79.38157640000001,
#   'Bulldog On The Block',
#   43.65065218852629,
#   -79.38414092873634,
#   'Coffee Shop'),
#  ('M5K',
#   'Downtown Toronto',
#   'Toronto Dominion Centre, Design Exchange',
#   43.6471768,
#   -79.38157640000001,
#   'The Chase',
#   43.650951982093595,
#   -79.37942201983014,
#   'New American Restaurant'),
#  ('M5K',
#   'Downtown Toronto',
#   'Toronto Dominion Centre, Design Exchange',
#   43.6471768,
#   -79.38157640000001,
#   "Assembly Chef's Hall",
#   43.650578865093934,
#   -79.3834119303614,
#   'Food Court'),
#  ('M5K',
#   'Downtown Toronto',
#   'Toronto Dominion Centre, Design Exchange',
#   43.6471768,
#   -79.38157640000001,
#   'Air Canada Club',
#   43.643224100030416,
#   -79.37915938219528,
#   'Lounge'),
#  ('M5K',
#   'Downtown Toronto',
#   'Toronto Dominion Centre, Design Exchange',
#   43.6471768,
#   -79.38157640000001,
#   'Brookfield Place',
#   43.646790641203026,
#   -79.37876938530562,
#   'Shopping Mall'),
#  ('M5K',
#   'Downtown Toronto',
#   'Toronto Dominion Centre, Design Exchange',
#   43.6471768,
#   -79.38157640000001,
#   'Cosmopolitan Toronto Centre Hotel & Spa',
#   43.64906432957466,
#   -79.37759759701125,
#   'Hotel'),
#  ('M5K',
#   'Downtown Toronto',
#   'Toronto Dominion Centre, Design Exchange',
#   43.6471768,
#   -79.38157640000001,
#   'iQ Food Co',
#   43.64748168603231,
#   -79.37910417362639,
#   'Fast Food Restaurant'),
#  ('M5K',
#   'Downtown Toronto',
#   'Toronto Dominion Centre, Design Exchange',
#   43.6471768,
#   -79.38157640000001,
#   'Royal Alexandra Theatre',
#   43.647255,
#   -79.38753,
#   'Theater'),
#  ('M5K',
#   'Downtown Toronto',
#   'Toronto Dominion Centre, Design Exchange',
#   43.6471768,
#   -79.38157640000001,
#   'Meridian Hall',
#   43.646292124205594,
#   -79.37602179505662,
#   'Concert Hall'),
#  ('M5K',
#   'Downtown Toronto',
#   'Toronto Dominion Centre, Design Exchange',
#   43.6471768,
#   -79.38157640000001,
#   'TOCA',
#   43.64543117726125,
#   -79.38705858895491,
#   'Italian Restaurant'),
#  ('M5K',
#   'Downtown Toronto',
#   'Toronto Dominion Centre, Design Exchange',
#   43.6471768,
#   -79.38157640000001,
#   'Jump',
#   43.64814738516352,
#   -79.37875242540652,
#   'American Restaurant'),
#  ('M5K',
#   'Downtown Toronto',
#   'Toronto Dominion Centre, Design Exchange',
#   43.6471768,
#   -79.38157640000001,
#   "Biff's Bistro",
#   43.647084825125084,
#   -79.37634231908494,
#   'French Restaurant'),
#  ('M5K',
#   'Downtown Toronto',
#   'Toronto Dominion Centre, Design Exchange',
#   43.6471768,
#   -79.38157640000001,
#   'Estiatorio Volos',
#   43.65032912559998,
#   -79.38453301297716,
#   'Greek Restaurant'),
#  ('M5K',
#   'Downtown Toronto',
#   'Toronto Dominion Centre, Design Exchange',
#   43.6471768,
#   -79.38157640000001,
#   'M Square Coffee Co',
#   43.65121797253777,
#   -79.38355459932247,
#   'Coffee Shop'),
#  ('M5K',
#   'Downtown Toronto',
#   'Toronto Dominion Centre, Design Exchange',
#   43.6471768,
#   -79.38157640000001,
#   'Craft Beer Market',
#   43.6498722789121,
#   -79.37839828995996,
#   'Beer Bar'),
#  ('M5K',
#   'Downtown Toronto',
#   'Toronto Dominion Centre, Design Exchange',
#   43.6471768,
#   -79.38157640000001,
#   'The Gabardine',
#   43.65098801064232,
#   -79.38122513218154,
#   'American Restaurant'),
#  ('M5K',
#   'Downtown Toronto',
#   'Toronto Dominion Centre, Design Exchange',
#   43.6471768,
#   -79.38157640000001,
#   'Delta Toronto Club Lounge',
#   43.64308454373067,
#   -79.38388489051405,
#   'Roof Deck'),
#  ('M5K',
#   'Downtown Toronto',
#   'Toronto Dominion Centre, Design Exchange',
#   43.6471768,
#   -79.38157640000001,
#   'Starbucks',
#   43.64621307149554,
#   -79.37908847368506,
#   'Coffee Shop'),
#  ('M5K',
#   'Downtown Toronto',
#   'Toronto Dominion Centre, Design Exchange',
#   43.6471768,
#   -79.38157640000001,
#   'Brooks Brothers',
#   43.646852351216,
#   -79.37944665991276,
#   'Clothing Store'),
#  ('M5K',
#   'Downtown Toronto',
#   'Toronto Dominion Centre, Design Exchange',
#   43.6471768,
#   -79.38157640000001,
#   'Marché Mövenpick',
#   43.6472616,
#   -79.3785998,
#   'Restaurant'),
#  ('M5K',
#   'Downtown Toronto',
#   'Toronto Dominion Centre, Design Exchange',
#   43.6471768,
#   -79.38157640000001,
#   'Sweet Lulu',
#   43.65055650489936,
#   -79.38117543224395,
#   'Asian Restaurant'),
#  ('M5K',
#   'Downtown Toronto',
#   'Toronto Dominion Centre, Design Exchange',
#   43.6471768,
#   -79.38157640000001,
#   'Ninki Izakaya',
#   43.65022782352305,
#   -79.38486260004564,
#   'Japanese Restaurant'),
#  ('M5K',
#   'Downtown Toronto',
#   'Toronto Dominion Centre, Design Exchange',
#   43.6471768,
#   -79.38157640000001,
#   'Tachi',
#   43.65059603893127,
#   -79.38339613055128,
#   'Sushi Restaurant'),
#  ('M5K',
#   'Downtown Toronto',
#   'Toronto Dominion Centre, Design Exchange',
#   43.6471768,
#   -79.38157640000001,
#   'John Allans',
#   43.651446635211904,
#   -79.38135389611388,
#   'Salon / Barbershop'),
#  ('M5K',
#   'Downtown Toronto',
#   'Toronto Dominion Centre, Design Exchange',
#   43.6471768,
#   -79.38157640000001,
#   "Ruth's Chris Steak House",
#   43.6499174,
#   -79.3857238,
#   'Steakhouse'),
#  ('M5K',
#   'Downtown Toronto',
#   'Toronto Dominion Centre, Design Exchange',
#   43.6471768,
#   -79.38157640000001,
#   'Mercatto',
#   43.6502431921682,
#   -79.38081989149896,
#   'Italian Restaurant'),
#  ('M5K',
#   'Downtown Toronto',
#   'Toronto Dominion Centre, Design Exchange',
#   43.6471768,
#   -79.38157640000001,
#   'Spirit of Hockey',
#   43.64704692224217,
#   -79.37753727586353,
#   'Sporting Goods Shop'),
#  ('M5K',
#   'Downtown Toronto',
#   'Toronto Dominion Centre, Design Exchange',
#   43.6471768,
#   -79.38157640000001,
#   'Szechuan Express',
#   43.6469728132212,
#   -79.37954884053248,
#   'Chinese Restaurant'),
#  ('M5K',
#   'Downtown Toronto',
#   'Toronto Dominion Centre, Design Exchange',
#   43.6471768,
#   -79.38157640000001,
#   'Fast Fresh Foods',
#   43.647707960663595,
#   -79.3795487376397,
#   'Salad Place'),
#  ('M5K',
#   'Downtown Toronto',
#   'Toronto Dominion Centre, Design Exchange',
#   43.6471768,
#   -79.38157640000001,
#   'Over Easy',
#   43.64807704204346,
#   -79.37759871575396,
#   'Breakfast Spot'),
#  ('M5K',
#   'Downtown Toronto',
#   'Toronto Dominion Centre, Design Exchange',
#   43.6471768,
#   -79.38157640000001,
#   "Druxy's",
#   43.648015481211395,
#   -79.37990651776452,
#   'Deli / Bodega'),
#  ('M5K',
#   'Downtown Toronto',
#   'Toronto Dominion Centre, Design Exchange',
#   43.6471768,
#   -79.38157640000001,
#   'Toronto Maple Leafs Hockey Club',
#   43.645786474455754,
#   -79.37980311832982,
#   'General Entertainment'),
#  ('M5K',
#   'Downtown Toronto',
#   'Toronto Dominion Centre, Design Exchange',
#   43.6471768,
#   -79.38157640000001,
#   'Starbucks',
#   43.650159,
#   -79.377793,
#   'Coffee Shop'),
#  ('M5K',
#   'Downtown Toronto',
#   'Toronto Dominion Centre, Design Exchange',
#   43.6471768,
#   -79.38157640000001,
#   'FLOCK Rotisserie + Greens',
#   43.65098849486318,
#   -79.38191708712704,
#   'Salad Place'),
#  ('M5K',
#   'Downtown Toronto',
#   'Toronto Dominion Centre, Design Exchange',
#   43.6471768,
#   -79.38157640000001,
#   'Kupfert & Kim (Brookfield Place)',
#   43.64640689131027,
#   -79.3791688653838,
#   'Gluten-free Restaurant'),
#  ('M5K',
#   'Downtown Toronto',
#   'Toronto Dominion Centre, Design Exchange',
#   43.6471768,
#   -79.38157640000001,
#   'Hilton',
#   43.6499459,
#   -79.385479,
#   'Hotel'),
#  ('M5K',
#   'Downtown Toronto',
#   'Toronto Dominion Centre, Design Exchange',
#   43.6471768,
#   -79.38157640000001,
#   "Victoria's Restaurant",
#   43.64929834396347,
#   -79.37643067251867,
#   'Restaurant'),
#  ('M5K',
#   'Downtown Toronto',
#   'Toronto Dominion Centre, Design Exchange',
#   43.6471768,
#   -79.38157640000001,
#   'Z-Teca Gourmet Burritos',
#   43.6480141803431,
#   -79.37911924716222,
#   'Burrito Place'),
#  ('M5K',
#   'Downtown Toronto',
#   'Toronto Dominion Centre, Design Exchange',
#   43.6471768,
#   -79.38157640000001,
#   'RBC Royal Bank',
#   43.645603382795834,
#   -79.38606457169753,
#   'Bank'),
#  ('M5K',
#   'Downtown Toronto',
#   'Toronto Dominion Centre, Design Exchange',
#   43.6471768,
#   -79.38157640000001,
#   'Colibri',
#   43.651041,
#   -79.384065,
#   'Taco Place'),
#  ('M5K',
#   'Downtown Toronto',
#   'Toronto Dominion Centre, Design Exchange',
#   43.6471768,
#   -79.38157640000001,
#   'Metropolitan Resto Bar',
#   43.65006166044848,
#   -79.3771814107564,
#   'Italian Restaurant'),
#  ('M5K',
#   'Downtown Toronto',
#   'Toronto Dominion Centre, Design Exchange',
#   43.6471768,
#   -79.38157640000001,
#   'Sushi-Q',
#   43.64773753191116,
#   -79.37969913096782,
#   'Sushi Restaurant'),
#  ('M5K',
#   'Downtown Toronto',
#   'Toronto Dominion Centre, Design Exchange',
#   43.6471768,
#   -79.38157640000001,
#   'Drake One Fifty',
#   43.649589523564934,
#   -79.38455694587901,
#   'Restaurant'),
#  ('M5K',
#   'Downtown Toronto',
#   'Toronto Dominion Centre, Design Exchange',
#   43.6471768,
#   -79.38157640000001,
#   'Toronto City Hall Rooftop Garden',
#   43.651230845735505,
#   -79.3837674874531,
#   'Garden'),
#  ('M5L',
#   'Downtown Toronto',
#   'Commerce Court, Victoria Hotel',
#   43.6481985,
#   -79.37981690000001,
#   'Mos Mos Coffee',
#   43.64815919753501,
#   -79.37874450467258,
#   'Café'),
#  ('M5L',
#   'Downtown Toronto',
#   'Commerce Court, Victoria Hotel',
#   43.6481985,
#   -79.37981690000001,
#   'Canoe',
#   43.647452066183476,
#   -79.38132001815676,
#   'Restaurant'),
#  ('M5L',
#   'Downtown Toronto',
#   'Commerce Court, Victoria Hotel',
#   43.6481985,
#   -79.37981690000001,
#   'Adelaide Club Toronto',
#   43.64927944291712,
#   -79.38192123284551,
#   'Gym / Fitness Center'),
#  ('M5L',
#   'Downtown Toronto',
#   'Commerce Court, Victoria Hotel',
#   43.6481985,
#   -79.37981690000001,
#   'Equinox Bay Street',
#   43.64809974034856,
#   -79.37998869411526,
#   'Gym'),
#  ('M5L',
#   'Downtown Toronto',
#   'Commerce Court, Victoria Hotel',
#   43.6481985,
#   -79.37981690000001,
#   'Brick Street Bakery',
#   43.6488151631615,
#   -79.38060468610949,
#   'Bakery'),
#  ('M5L',
#   'Downtown Toronto',
#   'Commerce Court, Victoria Hotel',
#   43.6481985,
#   -79.37981690000001,
#   'Pilot Coffee Roasters',
#   43.648835391245896,
#   -79.3809358125033,
#   'Coffee Shop'),
#  ('M5L',
#   'Downtown Toronto',
#   'Commerce Court, Victoria Hotel',
#   43.6481985,
#   -79.37981690000001,
#   'Hockey Hall Of Fame (Hockey Hall of Fame)',
#   43.646974451431056,
#   -79.37732323942681,
#   'Museum'),
#  ('M5L',
#   'Downtown Toronto',
#   'Commerce Court, Victoria Hotel',
#   43.6481985,
#   -79.37981690000001,
#   'Walrus Pub & Beer Hall',
#   43.64737470920577,
#   -79.37951515363918,
#   'Pub'),
#  ('M5L',
#   'Downtown Toronto',
#   'Commerce Court, Victoria Hotel',
#   43.6481985,
#   -79.37981690000001,
#   'DAVIDsTEA',
#   43.64650585612388,
#   -79.38014477491379,
#   'Tea Room'),
#  ('M5L',
#   'Downtown Toronto',
#   'Commerce Court, Victoria Hotel',
#   43.6481985,
#   -79.37981690000001,
#   'Maman',
#   43.64830873804684,
#   -79.38225333898805,
#   'Café'),
#  ('M5L',
#   'Downtown Toronto',
#   'Commerce Court, Victoria Hotel',
#   43.6481985,
#   -79.37981690000001,
#   'Dineen @CommerceCourt',
#   43.648250543365556,
#   -79.38012728220869,
#   'Coffee Shop'),
#  ('M5L',
#   'Downtown Toronto',
#   'Commerce Court, Victoria Hotel',
#   43.6481985,
#   -79.37981690000001,
#   'Café Plenty',
#   43.6491179354577,
#   -79.37831288380438,
#   'Café'),
#  ('M5L',
#   'Downtown Toronto',
#   'Commerce Court, Victoria Hotel',
#   43.6481985,
#   -79.37981690000001,
#   'Movenpick Cafe',
#   43.647686808930885,
#   -79.3772953884033,
#   'Café'),
#  ('M5L',
#   'Downtown Toronto',
#   'Commerce Court, Victoria Hotel',
#   43.6481985,
#   -79.37981690000001,
#   'Indigospirit',
#   43.64834987590252,
#   -79.38034747310336,
#   'Bookstore'),
#  ('M5L',
#   'Downtown Toronto',
#   'Commerce Court, Victoria Hotel',
#   43.6481985,
#   -79.37981690000001,
#   'King Taps',
#   43.648475974183,
#   -79.38205778358744,
#   'Gastropub'),
#  ('M5L',
#   'Downtown Toronto',
#   'Commerce Court, Victoria Hotel',
#   43.6481985,
#   -79.37981690000001,
#   "Pumpernickel's Deli",
#   43.64883150054619,
#   -79.38197006345457,
#   'Deli / Bodega'),
#  ('M5L',
#   'Downtown Toronto',
#   'Commerce Court, Victoria Hotel',
#   43.6481985,
#   -79.37981690000001,
#   'Chotto Matte',
#   43.646473,
#   -79.378782,
#   'Japanese Restaurant'),
#  ('M5L',
#   'Downtown Toronto',
#   'Commerce Court, Victoria Hotel',
#   43.6481985,
#   -79.37981690000001,
#   'Cactus Club Cafe',
#   43.6495520142626,
#   -79.38167072512041,
#   'American Restaurant'),
#  ('M5L',
#   'Downtown Toronto',
#   'Commerce Court, Victoria Hotel',
#   43.6481985,
#   -79.37981690000001,
#   'deKEFIR',
#   43.65043319523819,
#   -79.37939324949957,
#   'Ice Cream Shop'),
#  ('M5L',
#   'Downtown Toronto',
#   'Commerce Court, Victoria Hotel',
#   43.6481985,
#   -79.37981690000001,
#   'Dineen Coffee',
#   43.650497,
#   -79.378765,
#   'Café'),
#  ('M5L',
#   'Downtown Toronto',
#   'Commerce Court, Victoria Hotel',
#   43.6481985,
#   -79.37981690000001,
#   'Beerbistro',
#   43.64941904378835,
#   -79.37723726034164,
#   'Gastropub'),
#  ('M5L',
#   'Downtown Toronto',
#   'Commerce Court, Victoria Hotel',
#   43.6481985,
#   -79.37981690000001,
#   "Olly Fresco's",
#   43.646912231909276,
#   -79.37959661696463,
#   'Deli / Bodega'),
#  ('M5L',
#   'Downtown Toronto',
#   'Commerce Court, Victoria Hotel',
#   43.6481985,
#   -79.37981690000001,
#   'Kupfert & Kim (First Canadian Place)',
#   43.64854659465186,
#   -79.38162406470161,
#   'Gluten-free Restaurant'),
#  ('M5L',
#   'Downtown Toronto',
#   'Commerce Court, Victoria Hotel',
#   43.6481985,
#   -79.37981690000001,
#   'Petit Four Bakery',
#   43.647743692587085,
#   -79.37958814250598,
#   'Sandwich Place'),
#  ('M5L',
#   'Downtown Toronto',
#   'Commerce Court, Victoria Hotel',
#   43.6481985,
#   -79.37981690000001,
#   'Design Exchange',
#   43.64797219581623,
#   -79.38010382588462,
#   'Art Gallery'),
#  ('M5L',
#   'Downtown Toronto',
#   'Commerce Court, Victoria Hotel',
#   43.6481985,
#   -79.37981690000001,
#   "Hy's Steakhouse",
#   43.649504756476944,
#   -79.38291850488223,
#   'Steakhouse'),
#  ('M5L',
#   'Downtown Toronto',
#   'Commerce Court, Victoria Hotel',
#   43.6481985,
#   -79.37981690000001,
#   'Bymark',
#   43.647217284018005,
#   -79.38125188166379,
#   'Restaurant'),
#  ('M5L',
#   'Downtown Toronto',
#   'Commerce Court, Victoria Hotel',
#   43.6481985,
#   -79.37981690000001,
#   'John & Sons Oyster House',
#   43.65065642537144,
#   -79.38161285228475,
#   'Seafood Restaurant'),
#  ('M5L',
#   'Downtown Toronto',
#   'Commerce Court, Victoria Hotel',
#   43.6481985,
#   -79.37981690000001,
#   'Ki Modern Japanese + Bar',
#   43.647167,
#   -79.379608,
#   'Japanese Restaurant'),
#  ('M5L',
#   'Downtown Toronto',
#   'Commerce Court, Victoria Hotel',
#   43.6481985,
#   -79.37981690000001,
#   'Cosmopolitan Toronto Centre Hotel & Spa',
#   43.64906432957466,
#   -79.37759759701125,
#   'Hotel'),
#  ('M5L',
#   'Downtown Toronto',
#   'Commerce Court, Victoria Hotel',
#   43.6481985,
#   -79.37981690000001,
#   'Garrison Bespoke',
#   43.648102,
#   -79.376334,
#   'Tailor Shop'),
#  ('M5L',
#   'Downtown Toronto',
#   'Commerce Court, Victoria Hotel',
#   43.6481985,
#   -79.37981690000001,
#   'Starbucks',
#   43.647261,
#   -79.378599,
#   'Coffee Shop'),
#  ('M5L',
#   'Downtown Toronto',
#   'Commerce Court, Victoria Hotel',
#   43.6481985,
#   -79.37981690000001,
#   'Richmond Station',
#   43.65156872562108,
#   -79.37926594000328,
#   'American Restaurant'),
#  ('M5L',
#   'Downtown Toronto',
#   'Commerce Court, Victoria Hotel',
#   43.6481985,
#   -79.37981690000001,
#   'The Omni King Edward Hotel',
#   43.64919051601911,
#   -79.37600612640387,
#   'Hotel'),
#  ('M5L',
#   'Downtown Toronto',
#   'Commerce Court, Victoria Hotel',
#   43.6481985,
#   -79.37981690000001,
#   'The Chase',
#   43.650951982093595,
#   -79.37942201983014,
#   'New American Restaurant'),
#  ('M5L',
#   'Downtown Toronto',
#   'Commerce Court, Victoria Hotel',
#   43.6481985,
#   -79.37981690000001,
#   'Craft Beer Market',
#   43.6498722789121,
#   -79.37839828995996,
#   'Beer Bar'),
#  ('M5L',
#   'Downtown Toronto',
#   'Commerce Court, Victoria Hotel',
#   43.6481985,
#   -79.37981690000001,
#   'WVRST',
#   43.64496809087762,
#   -79.38137631843854,
#   'Beer Bar'),
#  ('M5L',
#   'Downtown Toronto',
#   'Commerce Court, Victoria Hotel',
#   43.6481985,
#   -79.37981690000001,
#   'John & Sons Oyster House',
#   43.65060229830571,
#   -79.38155510682869,
#   'Seafood Restaurant'),
#  ('M5L',
#   'Downtown Toronto',
#   'Commerce Court, Victoria Hotel',
#   43.6481985,
#   -79.37981690000001,
#   'The Adelaide Hotel Toronto',
#   43.6498312,
#   -79.3801639,
#   'Hotel'),
#  ('M5L',
#   'Downtown Toronto',
#   'Commerce Court, Victoria Hotel',
#   43.6481985,
#   -79.37981690000001,
#   'Toronto Athletic Club',
#   43.647359553534905,
#   -79.3811766566002,
#   'Gym'),
#  ...]

# %%
venues_df = pd.DataFrame(venues)
venues_df.columns = ['PostalCode', 'Borough', 'Neighborhood', 'BoroughLatitude', 'BoroughLongitude', 'VenueName', 'VenueLatitude', 'VenueLongitude', 'VenueCategory']
print(venues_df.shape)
venues_df.head()
# Out:
# (1614, 9)
#   PostalCode       Borough  ... VenueLongitude      VenueCategory
# 0        M4E  East Toronto  ...     -79.293942              Trail
# 1        M4E  East Toronto  ...     -79.297734  Health Food Store
# 2        M4E  East Toronto  ...     -79.297215                Pub
# 3        M4E  East Toronto  ...     -79.294647               Park
# 4        M4E  East Toronto  ...     -79.292869       Neighborhood
#
# [5 rows x 9 columns]

# %%
venues_df.groupby(["PostalCode", "Borough", "Neighborhood"]).count()
# Out:
#                                                                                 BoroughLatitude  ...  VenueCategory
# PostalCode Borough          Neighborhood                                                         ...
# M4E        East Toronto     The Beaches                                                       5  ...              5
# M4K        East Toronto     The Danforth West, Riverdale                                     42  ...             42
# M4L        East Toronto     India Bazaar, The Beaches West                                   22  ...             22
# M4M        East Toronto     Studio District                                                  41  ...             41
# M4N        Central Toronto  Lawrence Park                                                     3  ...              3
# M4P        Central Toronto  Davisville North                                                  7  ...              7
# M4R        Central Toronto  North Toronto West                                               24  ...             24
# M4S        Central Toronto  Davisville                                                       38  ...             38
# M4T        Central Toronto  Moore Park, Summerhill East                                       3  ...              3
# M4V        Central Toronto  Summerhill West, Rathnelly, South Hill, Forest ...               16  ...             16
# M4W        Downtown Toronto Rosedale                                                          4  ...              4
# M4X        Downtown Toronto St. James Town, Cabbagetown                                      43  ...             43
# M4Y        Downtown Toronto Church and Wellesley                                             75  ...             75
# M5A        Downtown Toronto Regent Park, Harbourfront                                        45  ...             45
# M5B        Downtown Toronto Garden District, Ryerson                                        100  ...            100
# M5C        Downtown Toronto St. James Town                                                   78  ...             78
# M5E        Downtown Toronto Berczy Park                                                      57  ...             57
# M5G        Downtown Toronto Central Bay Street                                               64  ...             64
# M5H        Downtown Toronto Richmond, Adelaide, King                                         93  ...             93
# M5J        Downtown Toronto Harbourfront East, Union Station, Toronto Islands               100  ...            100
# M5K        Downtown Toronto Toronto Dominion Centre, Design Exchange                        100  ...            100
# M5L        Downtown Toronto Commerce Court, Victoria Hotel                                  100  ...            100
# M5N        Central Toronto  Roselawn                                                          2  ...              2
# M5P        Central Toronto  Forest Hill North & West                                          4  ...              4
# M5R        Central Toronto  The Annex, North Midtown, Yorkville                              24  ...             24
# M5S        Downtown Toronto University of Toronto, Harbord                                   34  ...             34
# M5T        Downtown Toronto Kensington Market, Chinatown, Grange Park                        56  ...             56
# M5V        Downtown Toronto CN Tower, King and Spadina, Railway Lands, Harb...               16  ...             16
# M5W        Downtown Toronto Stn A PO Boxes                                                   94  ...             94
# M5X        Downtown Toronto First Canadian Place, Underground city                          100  ...            100
# M6G        Downtown Toronto Christie                                                         17  ...             17
# M6H        West Toronto     Dufferin, Dovercourt Village                                     16  ...             16
# M6J        West Toronto     Little Portugal, Trinity                                         41  ...             41
# M6K        West Toronto     Brockton, Parkdale Village, Exhibition Place                     22  ...             22
# M6P        West Toronto     High Park, The Junction South                                    22  ...             22
# M6R        West Toronto     Parkdale, Roncesvalles                                           14  ...             14
# M6S        West Toronto     Runnymede, Swansea                                               40  ...             40
# M7A        Downtown Toronto Queen's Park, Ontario Provincial Government                      35  ...             35
# M7Y        East Toronto     Business reply mail Processing Centre                            17  ...             17
#
# [39 rows x 6 columns]

# %%
# one hot encoding
toronto_onehot = pd.get_dummies(venues_df[['VenueCategory']], prefix="", prefix_sep="")

# add postal, borough and neighborhood column back to dataframe
toronto_onehot['PostalCode'] = venues_df['PostalCode'] 
toronto_onehot['Borough'] = venues_df['Borough'] 
toronto_onehot['Neighborhoods'] = venues_df['Neighborhood'] 

# move postal, borough and neighborhood column to the first column
fixed_columns = list(toronto_onehot.columns[-3:]) + list(toronto_onehot.columns[:-3])
toronto_onehot = toronto_onehot[fixed_columns]

print(toronto_onehot.shape)
toronto_onehot.head()
# Out:
# (1614, 237)
#   PostalCode       Borough  ... Women's Store  Yoga Studio
# 0        M4E  East Toronto  ...             0            0
# 1        M4E  East Toronto  ...             0            0
# 2        M4E  East Toronto  ...             0            0
# 3        M4E  East Toronto  ...             0            0
# 4        M4E  East Toronto  ...             0            0
#
# [5 rows x 237 columns]

# %%
toronto_grouped = toronto_onehot.groupby(["PostalCode", "Borough", "Neighborhoods"]).mean().reset_index()
print(toronto_grouped.shape)
toronto_grouped
# Out:
# (39, 237)
#    PostalCode           Borough  ... Women's Store  Yoga Studio
# 0         M4E      East Toronto  ...      0.000000     0.000000
# 1         M4K      East Toronto  ...      0.000000     0.023810
# 2         M4L      East Toronto  ...      0.000000     0.000000
# 3         M4M      East Toronto  ...      0.000000     0.024390
# 4         M4N   Central Toronto  ...      0.000000     0.000000
# 5         M4P   Central Toronto  ...      0.000000     0.000000
# 6         M4R   Central Toronto  ...      0.000000     0.041667
# 7         M4S   Central Toronto  ...      0.000000     0.000000
# 8         M4T   Central Toronto  ...      0.000000     0.000000
# 9         M4V   Central Toronto  ...      0.000000     0.000000
# 10        M4W  Downtown Toronto  ...      0.000000     0.000000
# 11        M4X  Downtown Toronto  ...      0.000000     0.000000
# 12        M4Y  Downtown Toronto  ...      0.000000     0.026667
# 13        M5A  Downtown Toronto  ...      0.000000     0.022222
# 14        M5B  Downtown Toronto  ...      0.000000     0.000000
# 15        M5C  Downtown Toronto  ...      0.000000     0.000000
# 16        M5E  Downtown Toronto  ...      0.000000     0.000000
# 17        M5G  Downtown Toronto  ...      0.000000     0.015625
# 18        M5H  Downtown Toronto  ...      0.010753     0.000000
# 19        M5J  Downtown Toronto  ...      0.000000     0.000000
# 20        M5K  Downtown Toronto  ...      0.000000     0.000000
# 21        M5L  Downtown Toronto  ...      0.000000     0.000000
# 22        M5N   Central Toronto  ...      0.000000     0.000000
# 23        M5P   Central Toronto  ...      0.000000     0.000000
# 24        M5R   Central Toronto  ...      0.000000     0.000000
# 25        M5S  Downtown Toronto  ...      0.000000     0.029412
# 26        M5T  Downtown Toronto  ...      0.000000     0.000000
# 27        M5V  Downtown Toronto  ...      0.000000     0.000000
# 28        M5W  Downtown Toronto  ...      0.000000     0.010638
# 29        M5X  Downtown Toronto  ...      0.000000     0.000000
# 30        M6G  Downtown Toronto  ...      0.000000     0.000000
# 31        M6H      West Toronto  ...      0.000000     0.000000
# 32        M6J      West Toronto  ...      0.000000     0.024390
# 33        M6K      West Toronto  ...      0.000000     0.000000
# 34        M6P      West Toronto  ...      0.000000     0.000000
# 35        M6R      West Toronto  ...      0.000000     0.000000
# 36        M6S      West Toronto  ...      0.000000     0.025000
# 37        M7A  Downtown Toronto  ...      0.000000     0.028571
# 38        M7Y      East Toronto  ...      0.000000     0.000000
#
# [39 rows x 237 columns]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
areaColumns = ['PostalCode', 'Borough', 'Neighborhoods']
freqColumns = []
for ind in np.arange(num_top_venues):
    try:
        freqColumns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        freqColumns.append('{}th Most Common Venue'.format(ind+1))
columns = areaColumns+freqColumns

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['PostalCode'] = toronto_grouped['PostalCode']
neighborhoods_venues_sorted['Borough'] = toronto_grouped['Borough']
neighborhoods_venues_sorted['Neighborhoods'] = toronto_grouped['Neighborhoods']

for ind in np.arange(toronto_grouped.shape[0]):
    row_categories = toronto_grouped.iloc[ind, :].iloc[3:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    neighborhoods_venues_sorted.iloc[ind, 3:] = row_categories_sorted.index.values[0:num_top_venues]

# neighborhoods_venues_sorted.sort_values(freqColumns, inplace=True)
print(neighborhoods_venues_sorted.shape)
neighborhoods_venues_sorted
# Out:
# (39, 13)
#    PostalCode  ...     10th Most Common Venue
# 0         M4E  ...                    Dog Run
# 1         M4K  ...            Bubble Tea Shop
# 2         M4L  ...                  Pet Store
# 3         M4M  ...               Neighborhood
# 4         M4N  ...                 Donut Shop
# 5         M4P  ...               Dessert Shop
# 6         M4R  ...                  Gift Shop
# 7         M4S  ...             Farmers Market
# 8         M4T  ...                    Dog Run
# 9         M4V  ...                       Bank
# 10        M4W  ...           Doner Restaurant
# 11        M4X  ...                     Market
# 12        M4Y  ...                  Gastropub
# 13        M5A  ...                 Shoe Store
# 14        M5B  ...       Fast Food Restaurant
# 15        M5C  ...                   Creperie
# 16        M5E  ...           Greek Restaurant
# 17        M5G  ...               Burger Joint
# 18        M5H  ...                  Bookstore
# 19        M5J  ...        Sporting Goods Shop
# 20        M5K  ...                   Tea Room
# 21        M5L  ...         Seafood Restaurant
# 22        M5N  ...                 Donut Shop
# 23        M5P  ...                 Donut Shop
# 24        M5R  ...  Middle Eastern Restaurant
# 25        M5S  ...                 Beer Store
# 26        M5T  ...                  Hotel Bar
# 27        M5V  ...        Rental Car Location
# 28        M5W  ...                       Park
# 29        M5X  ...         Seafood Restaurant
# 30        M6G  ...         Athletics & Sports
# 31        M6H  ...  Middle Eastern Restaurant
# 32        M6J  ...                   Boutique
# 33        M6K  ...                     Bakery
# 34        M6P  ...        Fried Chicken Joint
# 35        M6R  ...         Italian Restaurant
# 36        M6S  ...                       Park
# 37        M7A  ...      General Entertainment
# 38        M7Y  ...              Garden Center
#
# [39 rows x 13 columns]

# %%
kclusters = 5

toronto_grouped_clustering = toronto_grouped.drop(["PostalCode", "Borough", "Neighborhoods"], 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
len(kmeans.labels_)
# Out:
# 39

# %%
#create a new dataframe that includes the cluster as well as the top 10 venues for each neighborhood.
toronto_merged = toronto_df_new.copy()

# add clustering labels
toronto_merged["Cluster Labels"] = kmeans.labels_

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.drop(["Borough", "Neighborhoods"], 1).set_index("PostalCode"), on="PostalCode")

print(toronto_merged.shape)
toronto_merged.head() # check the last columns!
# Out:
# (39, 16)
#   PostalCode  ... 10th Most Common Venue
# 0        M4E  ...                Dog Run
# 1        M4K  ...        Bubble Tea Shop
# 2        M4L  ...              Pet Store
# 3        M4M  ...           Neighborhood
# 4        M4N  ...             Donut Shop
#
# [5 rows x 16 columns]

# %%
toronto_merged
# Out:
#    PostalCode  ...     10th Most Common Venue
# 0         M4E  ...                    Dog Run
# 1         M4K  ...            Bubble Tea Shop
# 2         M4L  ...                  Pet Store
# 3         M4M  ...               Neighborhood
# 4         M4N  ...                 Donut Shop
# 5         M4P  ...               Dessert Shop
# 6         M4R  ...                  Gift Shop
# 7         M4S  ...             Farmers Market
# 8         M4T  ...                    Dog Run
# 9         M4V  ...                       Bank
# 10        M4W  ...           Doner Restaurant
# 11        M4X  ...                     Market
# 12        M4Y  ...                  Gastropub
# 13        M5A  ...                 Shoe Store
# 14        M5B  ...       Fast Food Restaurant
# 15        M5C  ...                   Creperie
# 16        M5E  ...           Greek Restaurant
# 17        M5G  ...               Burger Joint
# 18        M5H  ...                  Bookstore
# 19        M5J  ...        Sporting Goods Shop
# 20        M5K  ...                   Tea Room
# 21        M5L  ...         Seafood Restaurant
# 22        M5N  ...                 Donut Shop
# 23        M5P  ...                 Donut Shop
# 24        M5R  ...  Middle Eastern Restaurant
# 25        M5S  ...                 Beer Store
# 26        M5T  ...                  Hotel Bar
# 27        M5V  ...        Rental Car Location
# 28        M5W  ...                       Park
# 29        M5X  ...         Seafood Restaurant
# 30        M6G  ...         Athletics & Sports
# 31        M6H  ...  Middle Eastern Restaurant
# 32        M6J  ...                   Boutique
# 33        M6K  ...                     Bakery
# 34        M6P  ...        Fried Chicken Joint
# 35        M6R  ...         Italian Restaurant
# 36        M6S  ...                       Park
# 37        M7A  ...      General Entertainment
# 38        M7Y  ...              Garden Center
#
# [39 rows x 16 columns]

# %%
# sort the results by Cluster Labels
print(toronto_merged.shape)
toronto_merged.sort_values(["Cluster Labels"], inplace=True)
toronto_merged
# Out:
# (39, 16)
#    PostalCode  ...     10th Most Common Venue
# 19        M5J  ...        Sporting Goods Shop
# 20        M5K  ...                   Tea Room
# 21        M5L  ...         Seafood Restaurant
# 24        M5R  ...  Middle Eastern Restaurant
# 25        M5S  ...                 Beer Store
# 26        M5T  ...                  Hotel Bar
# 27        M5V  ...        Rental Car Location
# 28        M5W  ...                       Park
# 29        M5X  ...         Seafood Restaurant
# 30        M6G  ...         Athletics & Sports
# 31        M6H  ...  Middle Eastern Restaurant
# 32        M6J  ...                   Boutique
# 33        M6K  ...                     Bakery
# 34        M6P  ...        Fried Chicken Joint
# 35        M6R  ...         Italian Restaurant
# 36        M6S  ...                       Park
# 37        M7A  ...      General Entertainment
# 18        M5H  ...                  Bookstore
# 38        M7Y  ...              Garden Center
# 16        M5E  ...           Greek Restaurant
# 1         M4K  ...            Bubble Tea Shop
# 2         M4L  ...                  Pet Store
# 3         M4M  ...               Neighborhood
# 5         M4P  ...               Dessert Shop
# 6         M4R  ...                  Gift Shop
# 7         M4S  ...             Farmers Market
# 17        M5G  ...               Burger Joint
# 9         M4V  ...                       Bank
# 11        M4X  ...                     Market
# 12        M4Y  ...                  Gastropub
# 13        M5A  ...                 Shoe Store
# 14        M5B  ...       Fast Food Restaurant
# 15        M5C  ...                   Creperie
# 22        M5N  ...                 Donut Shop
# 8         M4T  ...                    Dog Run
# 23        M5P  ...                 Donut Shop
# 10        M4W  ...           Doner Restaurant
# 4         M4N  ...                 Donut Shop
# 0         M4E  ...                    Dog Run
#
# [39 rows x 16 columns]

# %%
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, post, bor, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['PostalCode'], toronto_merged['Borough'], toronto_merged['Neighborhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup('{} ({}): {} - Cluster {}'.format(bor, post, poi, cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
